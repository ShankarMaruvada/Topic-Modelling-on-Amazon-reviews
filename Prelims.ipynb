# %%
data_dir = 'C:/Users/maruv/Desktop/DSB/LDA/'

# %%
import json
import os
import glob

# %%
import pandas as pd
import gzip

def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

# %%
df = getDF(data_dir+'reviews_Cell_Phones_and_Accessories_5.json.gz')

# %%
df
# Out:
#             reviewerID        asin                       reviewerName  \
# 0       A30TL5EWN6DFXT  120401325X                          christina
# 1        ASY55RVNIL0UD  120401325X                           emily l.
# 2       A2TMXE2AFO7ONB  120401325X                              Erica
# 3        AWJ0WZQYMYFQ4  120401325X                                 JM
# 4        ATX7CZYFXI1KW  120401325X                   patrice m rogoza
# 5        APX47D16JOP7H  120401325X                                RLH
# 6       A1JVVYYO7G56DS  120401325X                        Tyler Evans
# 7        A6FGO4TBZ3QFZ  3998899561                   Abdullah Albyati
# 8       A2JWEDW5FSVB0F  3998899561                               Adam
# 9        A8AJS1DW7L3JJ  3998899561                    Agata Majchrzak
# 10      A2YO4SCWAWNYBI  3998899561                      Alex Maslakov
# 11      A3AFELPYTZH90T  3998899561                          Baja Alan
# 12       A6Q0P54QSP11J  3998899561                      Olivia ysiak
# 13       ANMATY0L0HX6Y  3998899561                       Sasha Malkin
# 14      A1XBPVR8FE7TE1  3998899561                              tim g
# 15      A35C4777EXZZQH  3998899561                          Viktoriya
# 16       ACU3LCRX4A8RV  3998899561    Zonaldo Reefey "Zonaldo Reefey"
# 17      A1ZTTNS6SWFV52  6073894996  Alexander Graham Bell Very-Junior
# 18      A38EHCCO532RYI  6073894996                         amazonfan1
# 19      A2INSXDTE08WSJ  6073894996                             Barbie
# 20       A9NETBZNEW2TP  6073894996      Bernadette Mitchell "Lady Di"
# 21      A385HZRPXDDFCL  6073894996                                Bob
# 22       ALZQ9D8V53TI2  6073894996                        Bruce/Emily
# 23      A3VWU7S29LR2XX  6073894996                            Bryan S
# 24      A3TOHPW7ES23NZ  6073894996                              Cathy
# 25      A1LGWLFF0YD0KV  6073894996                   Daniel Fernandez
# 26      A2YODGM5RUZ7I1  6073894996                            DCGeek1
# 27      A29OXVQRZ154KX  6073894996                         Don Powell
# 28      A2U5NF3IH4YVKH  6073894996                      ebony winslow
# 29      A34XJA5OE33FP1  6073894996                                Hec
# ...                ...         ...                                ...
# 194409  A34KTJ4VWNBOHI  B00LH1QXC0                              Stina
# 194410   A4XPE5UGK51IA  B00LH1QXC0                          Tia Scott
# 194411  A2G7RZI15ZPCTH  B00LH1QZR8                               Ever
# 194412  A2V247ZQT9OJIT  B00LH1QZR8                            Natalia
# 194413   AF30DHAVSYNZ0  B00LH1QZR8                          Sasha DLH
# 194414  A34KTJ4VWNBOHI  B00LH1QZR8                              Stina
# 194415   A4XPE5UGK51IA  B00LH1QZR8                          Tia Scott
# 194416  A2G7RZI15ZPCTH  B00LH1R3C4                               Ever
# 194417  A3BXNEABWRWJ1R  B00LH1R3C4                               Jenn
# 194418  A1Q52UP42LZ6XY  B00LH1R3C4                               Nate
# 194419   AF30DHAVSYNZ0  B00LH1R3C4                          Sasha DLH
# 194420  A34KTJ4VWNBOHI  B00LH1R3C4                              Stina
# 194421  A2G7RZI15ZPCTH  B00LH1R5HW                               Ever
# 194422  A3BXNEABWRWJ1R  B00LH1R5HW                               Jenn
# 194423  A1Q52UP42LZ6XY  B00LH1R5HW                               Nate
# 194424   AF30DHAVSYNZ0  B00LH1R5HW                          Sasha DLH
# 194425  A34KTJ4VWNBOHI  B00LH1R5HW                              Stina
# 194426  A2G7RZI15ZPCTH  B00LH1R6SK                               Ever
# 194427  A3BXNEABWRWJ1R  B00LH1R6SK                               Jenn
# 194428  A1Q52UP42LZ6XY  B00LH1R6SK                               Nate
# 194429   AF30DHAVSYNZ0  B00LH1R6SK                          Sasha DLH
# 194430  A34KTJ4VWNBOHI  B00LH1R6SK                              Stina
# 194431  A1Q1Z7IR79G52A  B00LORXVUE   Ann Ingersoll Madison Rain "Ann"
# 194432  A388OX0ZF7OT8R  B00LORXVUE                            Chuck.C
# 194433  A2BLFCOPSMBOZ9  B00LORXVUE                      Dave Edmiston
# 194434  A1YMNTFLNDYQ1F  B00LORXVUE                    eyeused2loveher
# 194435  A15TX8B2L8B20S  B00LORXVUE                       Jon Davidson
# 194436  A3JI7QRZO1QG8X  B00LORXVUE                  Joyce M. Davidson
# 194437  A1NHB2VC68YQNM  B00LORXVUE                     Nurse Farrugia
# 194438  A1AG6U022WHXBF  B00LORXVUE                     Trisha Crocker
#
#          helpful                                         reviewText  overall  \
# 0         [0, 0]  They look good and stick good! I just don't li...      4.0
# 1         [0, 0]  These stickers work like the review says they ...      5.0
# 2         [0, 0]  These are awesome and make my phone look so st...      5.0
# 3         [4, 4]  Item arrived in great time and was in perfect ...      4.0
# 4         [2, 3]  awesome! stays on, and looks great. can be use...      5.0
# 5         [1, 2]  These make using the home button easy. My daug...      3.0
# 6         [0, 0]  Came just as described.. It doesn't come unstu...      5.0
# 7         [1, 2]  it worked for the first week then it only char...      1.0
# 8         [2, 3]  Good case, solid build. Protects phone all aro...      5.0
# 9         [1, 1]  This is a fantastic case. Very stylish and pro...      5.0
# 10        [0, 0]  this case fits perfectly on the s4 and keeps m...      5.0
# 11        [2, 3]  This is the first battery case I have had for ...      5.0
# 12        [3, 3]  Performs exactly as advertised . It's very  st...      5.0
# 13      [12, 16]  Unlike Most of the Rechargeable Battery cases,...      5.0
# 14        [1, 1]  Just what I needed. I needed a phone case for ...      5.0
# 15        [0, 0]  When there is no outlets, or chargers near by ...      5.0
# 16        [2, 3]  It works great. Doesn't heat up like crazy lik...      5.0
# 17        [0, 0]  Surprisingly, this inexpensive version works j...      5.0
# 18        [2, 3]  I have tested this against the griffin dual ou...      5.0
# 19        [0, 0]  It worked great for the first couple of weeks ...      1.0
# 20        [0, 0]  I love that it has two ports for my phone and ...      5.0
# 21        [0, 0]  just what you need, I am always having to char...      5.0
# 22        [0, 0]  does not have the need amps to charge things l...      3.0
# 23        [0, 0]  They are nothing special for sure, but it's ni...      4.0
# 24        [0, 0]  I have several chargers. Have more than one ve...      4.0
# 25        [0, 0]  I bought this a little skeptical. After I trie...      5.0
# 26        [0, 0]  I am disappointed that the 1A didn't work with...      2.0
# 27        [3, 4]  This is a nice charger but you can tell it was...      4.0
# 28        [0, 0]                   After a week only one side works      2.0
# 29        [0, 0]  Yo get exactly what you order in a timely fash...      4.0
# ...          ...                                                ...      ...
# 194409    [0, 0]  Perfect gift for a family member who loved sna...      5.0
# 194410    [0, 0]  My boyfriend also has this case and he adores ...      4.0
# 194411    [0, 0]  This is my favorite case in terms of feel. I'm...      5.0
# 194412    [0, 0]  This is such a cool case.  I got it for myself...      5.0
# 194413    [0, 0]               Punk retro texture!! Wonderful idea.      5.0
# 194414    [0, 0]  Get your stud their own studded case with this...      5.0
# 194415    [0, 0]  I got this case for the texture and I've been ...      5.0
# 194416    [0, 0]  Great idea and it works well. I love the feel ...      5.0
# 194417    [0, 0]  I love this galaxy-looking phone case! I paint...      5.0
# 194418    [0, 0]  This case somewhat reminds me of space. I saw ...      5.0
# 194419    [0, 0]  A leather case is truly a treat. It also is st...      5.0
# 194420    [0, 0]  Got this case for my spouse to go with his bla...      5.0
# 194421    [0, 0]  Another cool Valenz case. The pattern is why I...      5.0
# 194422    [0, 0]  I am not obsessed with this case. I read some ...      5.0
# 194423    [0, 0]  I've recently got a phone from my cousin in fa...      5.0
# 194424    [0, 0]  I've gotten in a habit of rubbing it back and ...      5.0
# 194425    [0, 0]  If you are looking for something unique, you h...      5.0
# 194426    [0, 0]                        Great case design and feel.      5.0
# 194427    [0, 0]  Feels fantastic. I feel like such a nerd buyin...      5.0
# 194428    [0, 0]  I get so many compliments on this case. It was...      5.0
# 194429    [0, 0]  Ahah, I love it. The case looks better than th...      5.0
# 194430    [0, 0]  As someone who owns an iPhone, I absolutely lo...      5.0
# 194431    [0, 0]  What a high quality cable. Right out of the pa...      5.0
# 194432    [0, 0]  This one actually works unlike some others I b...      4.0
# 194433    [0, 0]  I don't like the word "hate", so let's just sa...      5.0
# 194434    [0, 0]  Works great just like my original one. I reall...      5.0
# 194435    [0, 0]  Great product. Great packaging. High quality a...      5.0
# 194436    [0, 0]  This is a great cable, just as good as the mor...      5.0
# 194437    [0, 0]  I really like it becasue it works well with my...      5.0
# 194438    [0, 0]  product as described, I have wasted a lot of m...      5.0
#
#                                                   summary  unixReviewTime  \
# 0                                              Looks Good      1400630400
# 1                                   Really great product.      1389657600
# 2                                          LOVE LOVE LOVE      1403740800
# 3                                                   Cute!      1382313600
# 4               leopard home button sticker for iphone 4s      1359849600
# 5                                                    Cute      1381536000
# 6                                       best thing ever..      1377129600
# 7                                         not a good Idea      1384992000
# 8                                              Solid Case      1380067200
# 9                                            Perfect Case      1396483200
# 10                                     Just what I needed      1397347200
# 11                                               A Winner      1384905600
# 12                            Absolutely love the case !!      1386201600
# 13      Best Rechargeable Battery Case on the Market!!...      1380240000
# 14                                  Exactly what I needed      1392940800
# 15                                      5 star phone case      1397779200
# 16                                   SUPER DUPER QUALITY!      1377388800
# 17          Top Quality. Works like the Expensive Version      1368230400
# 18                                High power as promised!      1348012800
# 19                                               Horrible      1369785600
# 20                                               USB Port      1402012800
# 21                                            Works great      1385683200
# 22                                               it works      1368835200
# 23                         I like the fact they light up.      1402185600
# 24                                            Works great      1389398400
# 25                                            Works great      1379721600
# 26                        This doesn't work with my iPad.      1403481600
# 27                             Solid Charger but RF noisy      1363737600
# 28                                              Two Stars      1404345600
# 29                                                     Ok      1360195200
# ...                                                   ...             ...
# 194409                                 Makes a Great Gift      1405900800
# 194410                                         Ultra-cool      1405900800
# 194411                             Cool idea that worked!      1405641600
# 194412                              Very cool phone case.      1405900800
# 194413                                   cool, punky one!      1405641600
# 194414                                   Studs for a Stud      1405900800
# 194415                                 Very cool texture!      1405900800
# 194416                                               Feel      1405641600
# 194417                                        Bulletproof      1405728000
# 194418                                     One of a kind!      1405555200
# 194419                            leather in any weather.      1405641600
# 194420                                     Looks Great On      1405641600
# 194421                                            Feel it      1405641600
# 194422                                           Obsessed      1405728000
# 194423                 Never seen a case like this before      1405555200
# 194424                                      Well designed      1405641600
# 194425                         Grab Your Own Reptile Case      1405728000
# 194426                        Ssssssssuper Sssssatisfied.      1405641600
# 194427                                   Feel the python!      1405728000
# 194428                          You get what you pay for!      1405555200
# 194429                                         Yesssssss!      1405641600
# 194430                        Beautiful Color and Texture      1405641600
# 194431  Must have, high quality charging cable for ipa...      1405987200
# 194432                                          Long Wire      1405728000
# 194433                                     Awesome cable!      1405641600
# 194434                           This works just perfect!      1405900800
# 194435           Great replacement cable. Apple certified      1405900800
# 194436                                       Real quality      1405900800
# 194437  I really like it becasue it works well with my...      1405814400
# 194438              I have wasted a lot of money on cords      1405900800
#
#          reviewTime
# 0       05 21, 2014
# 1       01 14, 2014
# 2       06 26, 2014
# 3       10 21, 2013
# 4        02 3, 2013
# 5       10 12, 2013
# 6       08 22, 2013
# 7       11 21, 2013
# 8       09 25, 2013
# 9        04 3, 2014
# 10      04 13, 2014
# 11      11 20, 2013
# 12       12 5, 2013
# 13      09 27, 2013
# 14      02 21, 2014
# 15      04 18, 2014
# 16      08 25, 2013
# 17      05 11, 2013
# 18      09 19, 2012
# 19      05 29, 2013
# 20       06 6, 2014
# 21      11 29, 2013
# 22      05 18, 2013
# 23       06 8, 2014
# 24      01 11, 2014
# 25      09 21, 2013
# 26      06 23, 2014
# 27      03 20, 2013
# 28       07 3, 2014
# 29       02 7, 2013
# ...             ...
# 194409  07 21, 2014
# 194410  07 21, 2014
# 194411  07 18, 2014
# 194412  07 21, 2014
# 194413  07 18, 2014
# 194414  07 21, 2014
# 194415  07 21, 2014
# 194416  07 18, 2014
# 194417  07 19, 2014
# 194418  07 17, 2014
# 194419  07 18, 2014
# 194420  07 18, 2014
# 194421  07 18, 2014
# 194422  07 19, 2014
# 194423  07 17, 2014
# 194424  07 18, 2014
# 194425  07 19, 2014
# 194426  07 18, 2014
# 194427  07 19, 2014
# 194428  07 17, 2014
# 194429  07 18, 2014
# 194430  07 18, 2014
# 194431  07 22, 2014
# 194432  07 19, 2014
# 194433  07 18, 2014
# 194434  07 21, 2014
# 194435  07 21, 2014
# 194436  07 21, 2014
# 194437  07 20, 2014
# 194438  07 21, 2014
#
# [194439 rows x 9 columns]

# %%
import nltk as nt
noun_tags = ["NN","NNP","NNS","PRP","POS","WP","PRP$"]

# %%
df.columns[4:7]
# Out:
# Index(['reviewText', 'overall', 'summary'], dtype='object')

# %%
reviews = df.as_matrix(columns=df.columns[4:7])

# %%
len(reviews)
# Out:
# 194439

# %%
reviews[0]
# Out:
# array([ "They look good and stick good! I just don't like the rounded shape because I was always bumping it and Siri kept popping up and it was irritating. I just won't buy a product like this again",
#        4.0, 'Looks Good'], dtype=object)

# %%
def tags(sentence):
    array_words = nt.word_tokenize(sentence)
    tags = nt.pos_tag(array_words)
    return tags

# %%
def noun_words(review):
    nouns =[];
    all_tuples = tags(review)
    for one in all_tuples:
        for each in noun_tags:
            if(each == one[1]):
                nouns.append(one[0])
    return nouns

# %%
tags(reviews[0][0])
# Out:
# [('They', 'PRP'),
#  ('look', 'VBP'),
#  ('good', 'JJ'),
#  ('and', 'CC'),
#  ('stick', 'JJ'),
#  ('good', 'JJ'),
#  ('!', '.'),
#  ('I', 'PRP'),
#  ('just', 'RB'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('like', 'VB'),
#  ('the', 'DT'),
#  ('rounded', 'JJ'),
#  ('shape', 'NN'),
#  ('because', 'IN'),
#  ('I', 'PRP'),
#  ('was', 'VBD'),
#  ('always', 'RB'),
#  ('bumping', 'VBG'),
#  ('it', 'PRP'),
#  ('and', 'CC'),
#  ('Siri', 'NNP'),
#  ('kept', 'VBD'),
#  ('popping', 'VBG'),
#  ('up', 'RP'),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('irritating', 'VBG'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('just', 'RB'),
#  ('wo', 'MD'),
#  ("n't", 'RB'),
#  ('buy', 'VB'),
#  ('a', 'DT'),
#  ('product', 'NN'),
#  ('like', 'IN'),
#  ('this', 'DT'),
#  ('again', 'RB')]

# %%
noun_words(reviews[0][0])
# Out:
# ['They', 'I', 'shape', 'I', 'it', 'Siri', 'it', 'I', 'product']

# %%
reviews[0][0]
# Out:
# "They look good and stick good! I just don't like the rounded shape because I was always bumping it and Siri kept popping up and it was irritating. I just won't buy a product like this again"

# %%
total_nouns = []
for each in reviews:
    total_nouns.append(noun_words(each[0]))

# %%
total_nouns
# Out:
# [['They', 'I', 'shape', 'I', 'it', 'Siri', 'it', 'I', 'product'],
#  ['stickers',
#   'review',
#   'they',
#   'They',
#   'they',
#   'phone',
#   'They',
#   'I',
#   'share',
#   'them',
#   'my',
#   'sister'],
#  ['my', 'phone', 'look', 'I', 'it', 'year', 'CAN', 'YOU', 'YEAR', 'quality'],
#  ['Item',
#   'time',
#   'condition',
#   'I',
#   'buttons',
#   'they',
#   'deal',
#   'FREE',
#   'screen',
#   'protector',
#   'I',
#   'its',
#   'deal',
#   'it',
#   'it',
#   'they',
#   'it'],
#  ['awesome', 'stays', 'apple', 'products', 'nails', 'it', 'key'],
#  ['home',
#   'button',
#   'easy',
#   'My',
#   'daughter',
#   'I',
#   'them',
#   'I',
#   'them',
#   'Well',
#   'price'],
#  ['Came',
#   'described..',
#   'It',
#   'its',
#   'cute',
#   'People',
#   'I',
#   'them',
#   'it',
#   'driving'],
#  ['it', 'week', 'it', 'my', 'phone', '%', 'it', 'waste', 'money'],
#  ['case',
#   'build',
#   'phone',
#   'access',
#   'buttons',
#   'Battery',
#   'charges',
#   'battery',
#   'me',
#   'day',
#   'I',
#   'my',
#   'house',
#   'I',
#   'it',
#   'start'],
#  ['case',
#   'Very',
#   'protects',
#   'my',
#   'phone',
#   'access',
#   'buttons',
#   'features',
#   'loss',
#   'phone',
#   'reception',
#   'it',
#   'power',
#   'Great',
#   'buy'],
#  ['case', 's4', 'me', 'day', 'I', 'it'],
#  ['battery',
#   'case',
#   'I',
#   'my',
#   'Galaxy',
#   'S4',
#   'S4',
#   'weight',
#   'Galaxy',
#   'S4',
#   'It',
#   'battery',
#   'life',
#   'You',
#   'battery',
#   'phone',
#   'switch',
#   'leds',
#   'level',
#   'battery',
#   'case',
#   'time',
#   'Well',
#   'price'],
#  ['Performs',
#   'It',
#   'lots',
#   'boost',
#   'It',
#   'what',
#   'it',
#   'phone',
#   'star',
#   'experience',
#   'what',
#   'I',
#   'case',
#   'LOVE',
#   'LOVE',
#   'LOVE',
#   'it'],
#  ['Battery',
#   'cases',
#   'PowerBear',
#   'days',
#   'It',
#   'ones',
#   'I',
#   'light',
#   'design',
#   'case',
#   'I',
#   'Mophie',
#   'case',
#   'I',
#   'it',
#   'it',
#   'brick',
#   'your',
#   'pocket',
#   'Hence',
#   'I',
#   'it',
#   'PowerBear',
#   'I',
#   'it',
#   'I',
#   'difference',
#   'it',
#   'super',
#   'STRONG',
#   'manner',
#   'I',
#   'my',
#   'phone',
#   'times',
#   'its',
#   'shock',
#   'technology',
#   'thing',
#   'happen',
#   'case',
#   'phone',
#   'case',
#   'extension',
#   'my',
#   'phone',
#   'I',
#   'I',
#   'it',
#   'night',
#   'it',
#   'my',
#   'phone',
#   'case',
#   'I',
#   'life',
#   'days',
#   'I',
#   'compliments',
#   'I',
#   'people',
#   'my',
#   'job',
#   'fitness',
#   'center',
#   'community',
#   'Everybody',
#   'case',
#   'what',
#   'they',
#   'it',
#   'me',
#   '%',
#   'CHEAPER',
#   'brand',
#   'purchase',
#   'I',
#   'internet',
#   'I',
#   'my',
#   'family',
#   'time',
#   'Holidays',
#   'THANK',
#   'POWERBEAR'],
#  ['what',
#   'I',
#   'I',
#   'phone',
#   'case',
#   'myself',
#   'my',
#   'sons',
#   'I',
#   'replacement',
#   'batteries',
#   'case',
#   'I',
#   'thanks'],
#  ['outlets',
#   'chargers',
#   'its',
#   'Powerbear',
#   'rescue',
#   'my',
#   'husband',
#   'myself',
#   'purchase'],
#  ['It',
#   'crazy',
#   'ones',
#   'I',
#   'Its',
#   'power',
#   'case',
#   'S4',
#   'you',
#   'I',
#   'me',
#   'my',
#   'wife',
#   'I',
#   'its',
#   'power',
#   'bear..'],
#  ['version', 'variety', 'It', 'me', 'months', 'problem', 'value'],
#  ['I',
#   'output',
#   'current.This',
#   'unit',
#   'my',
#   'note',
#   'battery',
#   'ma.Griffin',
#   'ma',
#   'griffin',
#   'times',
#   'expensive.I',
#   'I',
#   'them',
#   'they',
#   'they',
#   'current.No',
#   'idea',
#   'they',
#   'I',
#   'they',
#   'I',
#   'them',
#   'I',
#   'testing',
#   'stock',
#   'charger',
#   'I'],
#  ['It', 'couple', 'weeks', 'it', 'completely..', 'waste', 'money'],
#  ['I',
#   'it',
#   'ports',
#   'my',
#   'phone',
#   'ipod',
#   'Who',
#   'things',
#   'socket',
#   'I',
#   'it'],
#  ['what', 'you', 'I', 'my', 'phone', 'I', 'item', 'charge'],
#  ['need', 'things', 'ipads', 'hp', 'touchpads', 'its'],
#  ['They', 'nothing', 'it', 'you', 'it', 'it', 'phones', 'car'],
#  ['I',
#   'chargers',
#   'vehicle',
#   'I',
#   'Nothing',
#   'frustrating',
#   'you',
#   'way',
#   'your',
#   'phone',
#   'you',
#   'it',
#   'my',
#   'products'],
#  ['I', 'I', 'it', 'I', 'It', 'it', 'months', 'I', 'review'],
#  ['I', 'work', 'my', 'iPad', 'what', 'I', 'adapter'],
#  ['charger',
#   'you',
#   'it',
#   'cheaply',
#   'China',
#   'it',
#   'phone',
#   'car',
#   'radio',
#   'LOTS',
#   'I',
#   'you',
#   'power',
#   'lines',
#   'radio',
#   'station',
#   'RF',
#   'shielding.I',
#   'it',
#   'stars',
#   'it',
#   'me',
#   'you',
#   'radio',
#   'you',
#   'it',
#   'stars'],
#  ['week', 'side', 'works'],
#  ['Yo', 'what', 'you', 'order', 'fashion', 'item', 'Great', 'you', 'me'],
#  ['product',
#   'my',
#   'Subaru',
#   "'s",
#   'console',
#   'Passengers',
#   'it',
#   'I',
#   'it',
#   'it',
#   'glow',
#   'it',
#   'years',
#   'performs'],
#  ['I', 'munch', 'things', 'years', 'jack', 'days'],
#  ['side',
#   'time',
#   'you',
#   'cables',
#   'side',
#   'stop',
#   'working',
#   'fuses',
#   'I',
#   'them',
#   'it',
#   'problem',
#   'Cheap',
#   'quality'],
#  ['it', 'i', 'i', 'thing', 'dont', 'my', 'her', 'phone'],
#  ['It', 'price', 'it', 'time', 'I', 'it', 'me', 'job'],
#  ['Did', 'it', 'it', 'piece', 'crap', 'I', 'it'],
#  ['product',
#   'handling',
#   'quality',
#   'it',
#   'time',
#   'condition',
#   'thank',
#   'you',
#   'everything'],
#  ['we',
#   'car',
#   'we',
#   'our',
#   'ipad',
#   'iohone',
#   'Can',
#   'power',
#   'my',
#   'Galaxy',
#   'Note',
#   'USB',
#   'devices',
#   'you',
#   'it',
#   'you'],
#  ['charger', 'devices', 'i', 'problems'],
#  ['product',
#   'month',
#   'Pros',
#   'it',
#   'Cool',
#   'Blue',
#   'feature',
#   'you',
#   'it',
#   'lighter',
#   'things',
#   'time',
#   '.Con',
#   'piece',
#   'overtime',
#   'I',
#   'tape',
#   'top',
#   'TOTAL',
#   'PROS:95',
#   '%',
#   'CONS:5',
#   '%'],
#  ['I',
#   'I',
#   'my',
#   'Tab',
#   'time',
#   'My',
#   'tab',
#   'power',
#   'port',
#   'charge',
#   'power',
#   'it'],
#  ['I',
#   'my',
#   'iphone',
#   'tablet',
#   'car',
#   'iphone',
#   'tablet',
#   'I',
#   'charge',
#   'iphoe',
#   'ipod',
#   'it'],
#  ['blue',
#   'light',
#   'touch',
#   'car',
#   'We',
#   'Samsung',
#   'Iphone',
#   'outlet',
#   'Nice'],
#  ['works',
#   'charges',
#   'ipads',
#   'tablets',
#   'smartphones',
#   'bluetooth',
#   'speakers',
#   'headsets',
#   'I',
#   'it',
#   'anyone',
#   'car',
#   'charger'],
#  ['I',
#   'USB',
#   'car',
#   'charger',
#   'stars',
#   'it',
#   'months',
#   'it',
#   'me.Pros',
#   'USB',
#   'ports',
#   'top',
#   'amps',
#   'slot',
#   'amps.-Fits',
#   'my',
#   'socket',
#   'I',
#   'my',
#   'my',
#   'iPhone',
#   'slot',
#   'slot',
#   'works',
#   'Android',
#   'phones',
#   'end',
#   'ones.-Has',
#   'blue',
#   'LED',
#   'light',
#   'you',
#   'it',
#   'USB',
#   'sockets',
#   'my',
#   'construction.-It',
#   'cost',
#   '-It',
#   'me',
#   'months.I',
#   'USB',
#   'charger',
#   'It',
#   'my',
#   'iPhone',
#   'phones',
#   'my',
#   'family',
#   'friends',
#   'slot',
#   'design',
#   'slot',
#   'design',
#   'one',
#   'their',
#   'device',
#   'I',
#   'my',
#   'cord',
#   'course',
#   'charger',
#   'I',
#   'slot',
#   'design',
#   'I',
#   'months',
#   'I',
#   'LED',
#   'light',
#   'It',
#   'week',
#   'I',
#   'what',
#   'problem',
#   'faulty',
#   'wiring',
#   'design',
#   'I',
#   'I',
#   'I',
#   'they',
#   'I',
#   'it',
#   'they',
#   'they',
#   'period',
#   'time.For',
#   'reason',
#   'it',
#   'I',
#   'slot',
#   'design',
#   'I',
#   'my',
#   'price',
#   'range'],
#  ['charger',
#   'chargers',
#   'It',
#   'job',
#   'my',
#   'phone',
#   'my',
#   'GPS',
#   'I',
#   'car',
#   'Great',
#   'value',
#   'wallet'],
#  ['I', 'minutes', 'it', 'it', 'product', 'thing', 'hazard', 'system'],
#  ['USB', 'Port', 'car', 'charger', 'people', 'go', 'Pair', 'cord', 'you'],
#  ['I', 'way', 'it', 'devices', 'quicker', 'GPS', 'it', 'it', 'battery', 'it'],
#  ['Bought', 'we', 'phones', 'time', 'car', 'port', 'Works'],
#  ['I',
#   'product',
#   'I',
#   'It',
#   'It',
#   'my',
#   'Iphone',
#   'my',
#   'phone',
#   'HTC',
#   'Evo',
#   'V',
#   'It',
#   'deal',
#   'It',
#   'something',
#   'price'],
#  ['I',
#   'retailers',
#   'factory',
#   'They',
#   'work',
#   'they',
#   'power',
#   'they',
#   'they',
#   'They',
#   'job.You',
#   'QC',
#   'product',
#   'they',
#   'work',
#   'year',
#   'use',
#   'par',
#   'they',
#   'replacements',
#   'hand',
#   'price',
#   'problem.Yes',
#   'they',
#   'my',
#   'iPhone',
#   'iPad',
#   'USB',
#   'device',
#   'I',
#   'LED',
#   'light',
#   'you',
#   'cars',
#   'travel',
#   'you',
#   'behind',
#   'hey',
#   'it',
#   'gems',
#   'complaints',
#   'I',
#   'couple',
#   'travel.Hope',
#   'trails'],
#  ['product', 'charger', 'I', 'Griffin', 'shipping'],
#  ['I',
#   'my',
#   'car',
#   'my',
#   'phone',
#   'my',
#   'iPod',
#   'It',
#   'light',
#   'night',
#   'Overall',
#   'deal'],
#  ['I', 'case', 'It', 'I', 'way', 'case', 'touch', 'rubber'],
#  ['idea',
#   'design',
#   'idea',
#   'it',
#   'paint',
#   'case',
#   'sealant',
#   'anything',
#   'It',
#   'effect',
#   'cost',
#   'paint',
#   'off.It'],
#  ['I',
#   'order',
#   'picture',
#   'description',
#   'page',
#   'green/orange',
#   'cover',
#   'it',
#   'day',
#   'product',
#   'cover',
#   'it',
#   'design'],
#  ['phone', 'case', 'I', 'I', 'I', 'them', '.thanks'],
#  ['case', 'its', 'silver', 'It', 'it', 'my', 'phone', 'It'],
#  ['price',
#   'You',
#   'order',
#   'cases',
#   'cell',
#   'phone',
#   'stores',
#   'I',
#   'mark',
#   'things'],
#  ['case', 'It', 'my', 'phone', 'I', 'it', 'time', 'time'],
#  ['item',
#   'design',
#   'cover',
#   'I',
#   'compliments',
#   'It',
#   'buy',
#   'I',
#   'anyone',
#   'look',
#   'their',
#   'phone'],
#  ['cover',
#   'phone',
#   'look',
#   'I',
#   'I',
#   'order',
#   'covers',
#   'money',
#   'my',
#   'phone'],
#  ['I',
#   'case',
#   'I',
#   'it',
#   'case',
#   'i',
#   'what',
#   'it',
#   'back',
#   'case',
#   'it',
#   'spots',
#   'Guess',
#   'deal',
#   'deal.would',
#   'purchase'],
#  ['color',
#   'person',
#   'protection',
#   'case',
#   'I',
#   'lot',
#   'compliments',
#   'case',
#   'it'],
#  ['Simple', 'way', 'your', 'wife', 'ability', 'look', 'her', 'phone'],
#  ['case',
#   'It',
#   'scratches',
#   'side',
#   'phone',
#   'its',
#   'it',
#   'Ive',
#   'my',
#   'phone',
#   'times',
#   'case',
#   'it',
#   'break',
#   'scratch',
#   'Ive',
#   'complements',
#   'case',
#   'it',
#   'bucks',
#   'I'],
#  ['case',
#   'it',
#   'thats',
#   'its',
#   'dollor',
#   'I',
#   'mine',
#   'Electromaster',
#   'It',
#   'fine',
#   'me',
#   'I',
#   'my',
#   'phone',
#   'phone',
#   'case',
#   'its',
#   'dollar',
#   'your',
#   'hopes',
#   'it',
#   'its',
#   'show',
#   'protection',
#   'you',
#   'your',
#   'phone',
#   'mile',
#   'outter',
#   'box'],
#  ['my', 'cases', 'I', 'one', 'my', 'phone', 'I', 'color', 'lot'],
#  ['It', 'it', 'It', 'it', 'paint', 'job', 'it'],
#  ['case',
#   'reason',
#   'left',
#   'skin',
#   'i',
#   'case',
#   'pink',
#   'my',
#   'color',
#   'i',
#   'anyone'],
#  ['Its',
#   'rubberized',
#   'it',
#   'picture',
#   'it',
#   'It',
#   'I',
#   'case',
#   'it',
#   'awhile',
#   'I',
#   'cases',
#   'I',
#   'my',
#   'shoes'],
#  ['weeks',
#   'time',
#   'price',
#   'It',
#   'pink/purple',
#   'spots',
#   'feel',
#   'it',
#   'I',
#   'it',
#   'it',
#   'me',
#   'trouble',
#   'I',
#   'covers'],
#  ['case', 'case', 'I', 'phone', 'It', 'I', 'compliments'],
#  ['cutest',
#   'case',
#   'EVER',
#   'I',
#   'it',
#   'it',
#   'I',
#   'rubber',
#   'because',
#   'uses',
#   'it',
#   'hem',
#   'sweater',
#   'case',
#   'my',
#   'phone',
#   'time',
#   'WOO',
#   'HOO'],
#  ['my', 'daughter', 'it', 'days', 'it', 'phone', 'your', 'judgement'],
#  ['charger', 'it', 'complaints', 'I', 'it', 'It', 'it'],
#  ['product',
#   'condition',
#   'It',
#   'Blackberry',
#   'charger',
#   'It',
#   'brand',
#   'price',
#   'I',
#   'you'],
#  ['product',
#   'my',
#   'Galaxy',
#   'S4',
#   'price',
#   'I',
#   'work',
#   'car',
#   'incase',
#   'I',
#   'my',
#   'charger'],
#  ['I',
#   'model',
#   'you',
#   'it',
#   'you',
#   'road',
#   'you',
#   'it',
#   'it',
#   'you',
#   'it',
#   'charging',
#   'needs',
#   'end',
#   'phones',
#   'it',
#   'them',
#   'you'],
#  ['I',
#   'charger',
#   'year',
#   'it',
#   'chargers',
#   'folding',
#   'blades',
#   'chargers',
#   'Blackberry',
#   'models',
#   'adapters',
#   'countries'],
#  ['problems', 'it', 'what', 'it', 'it', 'USB', 'it', 'wall', 'charger'],
#  ['Great',
#   'So',
#   'charger',
#   'it',
#   'years',
#   'phones',
#   'Iphone',
#   'Galaxy',
#   'phone',
#   'it',
#   'side',
#   'portal',
#   'it',
#   'Judy',
#   'it',
#   'bit',
#   'charger',
#   'it',
#   'it',
#   'usb'],
#  ['phone', 'charger', 'job', 'price', 'anyone', 'it'],
#  ['Works',
#   'We',
#   'travel',
#   'it',
#   'our',
#   'luggage',
#   'year',
#   'price',
#   'USB',
#   'charger',
#   'our',
#   'Galaxy',
#   'S3',
#   'Note'],
#  ['I',
#   'charger',
#   'quick',
#   'I',
#   'convenience',
#   'store',
#   'charger',
#   'price',
#   'charger',
#   'great.Pros',
#   'cord',
#   'length',
#   'you',
#   'bed',
#   'I',
#   'my',
#   'phone',
#   'I',
#   'down.Cons',
#   'plug',
#   'nothing',
#   'connecter',
#   'place',
#   '%',
#   'time',
#   'It',
#   'NOT',
#   'you',
#   'it',
#   'it',
#   'charge',
#   'My',
#   'phone',
#   'port',
#   'worn',
#   'my',
#   'issue.If',
#   'you',
#   'charger',
#   'price'],
#  ['Bought',
#   'charger',
#   'house',
#   'my',
#   'charger',
#   'my',
#   'Nice',
#   'cable',
#   'tons',
#   'charges',
#   'my',
#   'Galaxy',
#   'S3'],
#  ['charger',
#   'week',
#   'ad',
#   'it',
#   'my',
#   'Samsung',
#   'Galaxy',
#   'S3',
#   'They',
#   'chargers'],
#  ['Charger',
#   'First',
#   'I',
#   'it',
#   'it',
#   'plus',
#   'me',
#   'Second',
#   'I',
#   'it',
#   'it',
#   'its',
#   'Galaxy',
#   'S',
#   'Blackberry',
#   'lot',
#   'things',
#   'I',
#   'what',
#   'heck',
#   'its',
#   'cheap',
#   'what',
#   'I',
#   'Well',
#   'I',
#   'it',
#   'today',
#   'it',
#   'try',
#   'work',
#   'my',
#   'Galaxy',
#   'S4',
#   'it',
#   '%',
#   '%',
#   'minutes',
#   'i',
#   'it',
#   'cord',
#   'plus',
#   'me',
#   'your',
#   'charger',
#   'cord',
#   'price',
#   'one',
#   'update',
#   'what',
#   'reviewer',
#   'quality',
#   'chargers',
#   'I',
#   'mine',
#   'weeks',
#   'it',
#   'charger',
#   'length'],
#  ['I',
#   'backup',
#   'work',
#   'It',
#   'my',
#   'SGS4',
#   'I',
#   'charger',
#   'Samsung',
#   'Galaxy',
#   'S4'],
#  ['charger',
#   'Samsung',
#   'Galaxy',
#   'S4',
#   'it',
#   'phone',
#   'fast',
#   'price',
#   'Highly',
#   'product'],
#  ['product',
#   'i',
#   'order',
#   'future',
#   'money',
#   'you',
#   'car',
#   'charger',
#   'one',
#   'you'],
#  ['port',
#   'it',
#   'phone',
#   'fine',
#   'I',
#   'it',
#   'reach',
#   'i',
#   'phone',
#   'passenger',
#   'seat',
#   'car',
#   'its',
#   'problem',
#   'it',
#   'section',
#   'stress',
#   'charge',
#   'port',
#   'your',
#   'phone',
#   'people',
#   'it'],
#  ['I',
#   'chargers',
#   'my',
#   'sister',
#   'girlfriend',
#   'They',
#   'Samsung',
#   'Galaxy',
#   'phones',
#   'car',
#   'charger',
#   'OEM',
#   'fanboy',
#   'I',
#   'I',
#   'couple',
#   'them',
#   'what',
#   'mail',
#   'price.I',
#   'I',
#   'OEM',
#   'Samsung',
#   'car',
#   'chargers',
#   'mail',
#   'bags',
#   'part',
#   'barcodes',
#   'kind',
#   'you',
#   'new/refurb',
#   'phone',
#   'price',
#   'benefits',
#   'OEM',
#   'generic',
#   'output',
#   'reliability',
#   'top',
#   'list'],
#  ['I',
#   'my',
#   'Samsung',
#   'Charge',
#   'It',
#   'Verizon',
#   'charger',
#   'I',
#   'car',
#   'charger',
#   'thanks',
#   'price'],
#  ['It', 'what', 'it', 'I', 'lame'],
#  ['Charger', 'issues', 'it', 'I', 'it', 'cord', 'chargers', 'I', 'I', 'it'],
#  ['It', 'issues', 'thing', 'i', 'Connect', 'it', 'my', 't989', 'fail'],
#  ['store',
#   'town',
#   'their',
#   'name',
#   'anything',
#   'stock',
#   'they',
#   'anything',
#   'stock',
#   'it',
#   'junk',
#   'I',
#   'cord',
#   'amazon',
#   'fraction',
#   'price',
#   'I',
#   'junk',
#   'store',
#   'cord',
#   'months',
#   'I',
#   'time',
#   'charger',
#   'cords',
#   'amazon',
#   'work',
#   'I',
#   'car',
#   'charger',
#   'it',
#   'junk',
#   'you',
#   'store',
#   'Samsung',
#   'brand',
#   'charger',
#   'their',
#   'junk'],
#  ['lengthEasy', 'chargingI', 'it', 'persons', 'who', 'their', 'phone', 'lot'],
#  ['it', 'mo', 'you', 'price', 'it', 'I', 'them'],
#  ['JUNK',
#   'product',
#   'I',
#   'my',
#   'Samsung',
#   'S2',
#   'phone',
#   'OEM',
#   'charger',
#   'lights',
#   'phone',
#   'its',
#   'nothing',
#   'happens',
#   'I',
#   'I',
#   'product',
#   'it',
#   'your',
#   'car',
#   'hours',
#   'your',
#   'phone',
#   'recharge',
#   'you',
#   'charger',
#   'DO',
#   'NOT',
#   'product.If',
#   'you',
#   'car',
#   'charger',
#   'your',
#   'Samsung',
#   'S2',
#   'I',
#   'Motorola',
#   'Vehicle',
#   'Power',
#   'Adapter',
#   'It'],
#  ['car',
#   'charger',
#   'your',
#   'phones',
#   'my',
#   'phone',
#   'I',
#   'it',
#   'anyone',
#   'your',
#   'charger'],
#  ['Samsung',
#   'car',
#   'charger',
#   'month',
#   'period',
#   'I',
#   'fuse',
#   'unit',
#   'I',
#   'it',
#   'I',
#   'it',
#   'vehicle',
#   'chargers'],
#  ['WHAT',
#   'PRICE',
#   'RIGHT',
#   'OUT',
#   'THE',
#   'BOX',
#   'PLUG',
#   'N',
#   'UPLOAD',
#   'SUM',
#   'JUICE',
#   'IF',
#   'DROPPING',
#   'IT',
#   'REPEATEDLY',
#   'ON',
#   'THE',
#   'FLOORBOARD',
#   'OR',
#   'OCCASIONALLY',
#   'STUFFING',
#   'IT',
#   'IN',
#   'CONSOLE',
#   'TO',
#   'HIDE',
#   'CAUSED',
#   'FAILURE',
#   'BUT',
#   'SOON',
#   'THE',
#   'GREEN',
#   'LIGHT',
#   'FAILED',
#   'TO',
#   'LIGHT',
#   'AND',
#   'PHONES',
#   'DISPLAY',
#   'SHOWEDIT',
#   'WAS',
#   "N'T",
#   'CHARGING',
#   'SO',
#   'EITHER',
#   'SPEND',
#   'SEVERAL',
#   'MORE',
#   'DOLLARS',
#   'FOR',
#   'ONE',
#   'WITHA',
#   'HEAVIER',
#   'CORD/STRONGER',
#   'SHELL',
#   'OR',
#   'IT',
#   'A',
#   'DELICATE',
#   'FLOWER'],
#  ['Sprint', 'item', 'OEM', 'party', 'market'],
#  ['car', 'couple', 'days', 'My', 'phone', 'it'],
#  ['charger', 'I', 'fact', 'LED', 'it', 'it', 'phone', 'Great', 'bargain'],
#  ['I`m',
#   'expert',
#   'cell',
#   'phone',
#   'chargers',
#   'thing',
#   'its',
#   'fireworks',
#   'hotel',
#   'parties',
#   'Its',
#   'charger',
#   'it',
#   'I',
#   'it'],
#  ['I', 'charger', 'couple', 'months', 'Its', 'charger', 'It', 'my', 'phone'],
#  ['It',
#   'Samsung',
#   'brand..works',
#   'my',
#   'Android',
#   'phones..Galaxy',
#   'Nexus',
#   'Galaxy',
#   'S2',
#   'S3',
#   'it',
#   'anyone',
#   'microUSB',
#   'phone'],
#  ['I',
#   'car',
#   'charger',
#   'it',
#   'worksgreat',
#   'thing',
#   'store',
#   'times',
#   'price'],
#  ['oem',
#   'car',
#   'charger',
#   'it',
#   'my',
#   'galaxy',
#   'S2',
#   'week',
#   'I',
#   'Galaxy',
#   'S3',
#   'it',
#   'I',
#   'product'],
#  ['You', 'it', 'place', 'it', 'I', 'Verizon', 'charger'],
#  ['charger', 'It', 'Samsung', 'charger', 'I', 'it', 'I', 'it'],
#  ['I',
#   'charger',
#   'my',
#   'GS2',
#   'Straight',
#   'Talk',
#   'charger',
#   'phone',
#   'fine',
#   'quality',
#   'product',
#   'feeling',
#   'chargers',
#   'I',
#   'past'],
#  ['thing',
#   'it',
#   'today',
#   'it',
#   'I',
#   'day',
#   'window',
#   'days',
#   'quality',
#   'it',
#   'who',
#   'What',
#   'waste',
#   'money'],
#  ['Hope', 'it', 'My', 'one', 'light', 'you'],
#  ['es',
#   'un',
#   'cable',
#   'para',
#   'carro',
#   'calidad',
#   'samsung',
#   'tengo',
#   'algun',
#   'sin',
#   'ningun',
#   'problema'],
#  ['I',
#   'car',
#   'charges',
#   'they',
#   'uses',
#   'car',
#   'harder',
#   'it',
#   'my',
#   'phone',
#   'IT',
#   'LOVE',
#   'IT',
#   'LOVE',
#   'IT',
#   'thing'],
#  ['kind',
#   'cheap-looking',
#   'I',
#   'OEM',
#   'car',
#   'charger',
#   'I',
#   'my',
#   'phone',
#   'springs',
#   'side',
#   'force',
#   'car',
#   'port',
#   'cable',
#   'rubber',
#   'connector',
#   'kind',
#   'stiff',
#   'AND',
#   'your',
#   'phone',
#   'go',
#   'bit',
#   'hassle',
#   'It',
#   'I',
#   'it',
#   'though.UPDATE',
#   'month'],
#  ['I',
#   'months',
#   'it',
#   'it',
#   'I',
#   'Quality',
#   'product.The',
#   'cord',
#   'longer',
#   'it',
#   'length'],
#  ['cord', 'trick', 'Bought', 'diff', 'rooms', 'work'],
#  ['charger',
#   'it',
#   'USB',
#   'connection',
#   'it',
#   'material',
#   'it',
#   'charge',
#   'i',
#   'it'],
#  ['I',
#   'phone',
#   'chargers',
#   'weeks',
#   'I',
#   'I',
#   'them',
#   'chargers',
#   'cell',
#   'phones',
#   'I'],
#  ['Got',
#   'OEM',
#   'cord',
#   'cord',
#   'itself',
#   'plug',
#   'OEM',
#   'crap',
#   'Took',
#   'times',
#   'unit',
#   'cord',
#   'OEM',
#   'plug',
#   'it',
#   'you',
#   'cord',
#   'its',
#   'ok',
#   'it',
#   'OEM',
#   'plug',
#   'price',
#   'cord',
#   'it',
#   'value',
#   'I',
#   'markings',
#   'OEM',
#   'it'],
#  ['I',
#   'product',
#   'manner',
#   'I',
#   'it',
#   'gift',
#   'it',
#   'item',
#   'I',
#   'product',
#   'product',
#   'time'],
#  ['It', 'days', 'I', 'itself', 'point', 'it', 'I', 'cord', 'sprint'],
#  ['delivery'],
#  ['I', 'Samsung', 'product', 'counterfiet', 'It', 'my', 'phone'],
#  ['sansung',
#   'galaxy',
#   'travel',
#   'charger',
#   'It',
#   'cherry',
#   'cake',
#   'it',
#   'factory',
#   'l',
#   'phone'],
#  ['Had',
#   'marking',
#   'samsung',
#   'product',
#   'cord',
#   'stop',
#   'days',
#   'I',
#   'it',
#   'you',
#   'product',
#   'amazon',
#   'it',
#   'it'],
#  ['First',
#   'charger',
#   'it',
#   'ports',
#   'reviews',
#   'cord',
#   'feet',
#   'what',
#   'I',
#   'I',
#   'foot',
#   'cord',
#   'bit',
#   'purpose',
#   'I',
#   'it',
#   'my',
#   'car',
#   'I',
#   'cord',
#   'dangling',
#   'length',
#   'bonus',
#   'I',
#   'rating',
#   "'s",
#   'lack',
#   'description',
#   'and/or',
#   'consistency',
#   'I',
#   'product',
#   'image',
#   'I',
#   'it',
#   'style',
#   'adapter',
#   'I',
#   'shape',
#   'USB',
#   'port',
#   'side',
#   'I',
#   'shape',
#   'USB',
#   'port',
#   'end',
#   'hmm',
#   'way',
#   'sum',
#   'charger',
#   'connectivity',
#   'it',
#   'Samsung',
#   'Cord',
#   'length',
#   'style',
#   'it',
#   'seller'],
#  ['it',
#   'charger',
#   'dirt',
#   'cheap',
#   'shipping',
#   'item',
#   'I',
#   'they',
#   'batteries',
#   'my',
#   'phone'],
#  ['i',
#   'charger',
#   'cable',
#   'it',
#   'what',
#   'phone',
#   'length',
#   'phone',
#   'plain',
#   'sight',
#   'wall',
#   'receptical'],
#  ['charger',
#   'battery',
#   'my',
#   'Samsung',
#   'Galaxy',
#   'S2',
#   'i9100',
#   'properly.When',
#   'I',
#   'it',
#   'my',
#   'S2',
#   'screen',
#   'cell',
#   'way'],
#  ['charger', 'one', 'my', 'phone', 'It', 'buy', 'price'],
#  ['works', 'our', 'phones', 'charger', 'phones', 'price'],
#  ['Was',
#   'time.Wall',
#   'adapter',
#   'what',
#   'I',
#   'Quick-Charge',
#   'ad',
#   'states',
#   'Whole',
#   'reason',
#   'I',
#   'chager',
#   'micro',
#   'usb',
#   'it',
#   'cheaply',
#   'end',
#   'working',
#   'my',
#   'phone',
#   'its',
#   'usd',
#   'I',
#   'it',
#   'devices',
#   'adapters',
#   'it',
#   'problems',
#   'Will',
#   'order',
#   'Amazon',
#   'Again',
#   'orders',
#   'Defect',
#   'Probuct',
#   'Ugh'],
#  ['I', 'problems', 'it', 'It', 'charger', 'Galaxy', 'S'],
#  ['I',
#   'product',
#   'what',
#   'I',
#   'I',
#   'complaints',
#   'shipping',
#   'condition',
#   'product',
#   'it',
#   'my',
#   'house',
#   'problem',
#   'I',
#   'micro',
#   'usb',
#   'cable',
#   'charger',
#   'it',
#   'companies',
#   'chargers',
#   'Amazon',
#   'part',
#   'charger',
#   'micro',
#   'usb',
#   'cord',
#   'cord',
#   'cord',
#   'part',
#   'charger',
#   'I',
#   'issue',
#   'charger',
#   'I',
#   'my',
#   'note',
#   'It',
#   'cord',
#   'foot',
#   'cord',
#   'its',
#   'quality',
#   'part',
#   'charger',
#   'micro',
#   'plugs'],
#  ['thank',
#   'you',
#   'it',
#   'disappoint',
#   'job',
#   'I',
#   'phone',
#   'galaxy',
#   'surprise',
#   'etc'],
#  ['I', 'it', 'It', 'my', 'phone', 'cord', 'I', 'it', 'home', 'work'],
#  ['nutshell',
#   'NOT',
#   'OEM',
#   'charger',
#   'it',
#   'Samsung',
#   'markings',
#   'it',
#   'Samsung',
#   'phone',
#   'it',
#   'meant',
#   'market',
#   'it',
#   'counterfeit',
#   'I',
#   'UpdateThe',
#   'seller',
#   'amends',
#   'me',
#   'replacement',
#   'chargers',
#   'while',
#   'it',
#   'garbage',
#   'It',
#   'my',
#   'phone',
#   'fact',
#   'it',
#   'phone',
#   'product',
#   'It',
#   'markings',
#   'it',
#   'phone',
#   'DO',
#   'NOT',
#   'THIS',
#   'PRODUCT'],
#  ['weeks',
#   'my',
#   'charger',
#   'i',
#   'it',
#   'plug',
#   'charger',
#   'i',
#   'my',
#   'money',
#   'it',
#   'it'],
#  ['I',
#   'purchase',
#   'cable',
#   'option',
#   'flexibility',
#   'use',
#   'USB',
#   'cable',
#   'chargers',
#   'quality',
#   'travel',
#   'charger'],
#  ['charges', 'me', 'way', 'doubles', 'my', 'battery', 'liek', 'case', 'color'],
#  ['color',
#   'my',
#   'friends',
#   'me',
#   'I',
#   'it',
#   'They',
#   'I',
#   'them',
#   'I',
#   'it',
#   'Great',
#   'case',
#   'powers',
#   'me',
#   'VERY',
#   'Matches',
#   'my',
#   'PERFECTLY'],
#  ['I', 'it', 'ads', '%', 'battery', 'I', 'day', 'case'],
#  ['quality',
#   'product',
#   'I',
#   'case',
#   'it',
#   'sidekick',
#   'phone',
#   'my',
#   'phone',
#   'thanks',
#   'name',
#   'case',
#   'stars'],
#  ['case', 'me', 'my', 'day', 'my', 'phone', 'dying', 'color'],
#  ['Bought',
#   'one',
#   'me',
#   'wife',
#   'phone',
#   'protector',
#   'case',
#   'charge',
#   'day',
#   'complaints'],
#  ['PowerBear',
#   'case',
#   'lifesaver',
#   'I',
#   'texture',
#   'case',
#   'Highly',
#   'recommend'],
#  ['case', 'color', 'Phone', 'dies', 'it'],
#  ['I', 'it', 'game', 'steps', 'i', 'case', 'my', 'phone', 'i', 'it', 'It'],
#  ['I', 'something', 'my', 'wife', 'case', 'its', 'price', 'it'],
#  ['it',
#   'case',
#   'what',
#   'I',
#   'I',
#   'design',
#   'it',
#   'protects',
#   'my',
#   'case',
#   'I',
#   'it'],
#  ['phone', 'case', 'it', 'alot', 'it', 'it', 'it'],
#  ['heart',
#   'you',
#   'iPhone',
#   'piece',
#   'case',
#   'fits',
#   'glove',
#   'weeks',
#   'case',
#   'recommend'],
#  ['pice',
#   'snaps',
#   'sides',
#   'backing',
#   'piece',
#   'Came',
#   'scuffed',
#   'paint',
#   'pieces',
#   'it',
#   'I',
#   'it',
#   'it',
#   'click',
#   'pieces'],
#  ['Great',
#   'case',
#   'my',
#   'phone',
#   'Protects',
#   'me',
#   'access',
#   'button',
#   'i',
#   'it'],
#  ['power', 'cases', 'speaker', 'sound', 'port', 'back', 'listening'],
#  ['Wow',
#   'What',
#   'battery',
#   'case',
#   'I',
#   'sister',
#   'her',
#   'phone',
#   'order',
#   'me',
#   'my',
#   'sister',
#   'battery',
#   'case-mine',
#   'my',
#   'phone',
#   'my',
#   'sister',
#   "'s",
#   'her',
#   'phone',
#   'guys',
#   'you',
#   'power',
#   'your',
#   'phone',
#   'we',
#   'juice',
#   'go',
#   'we',
#   'case',
#   'our',
#   'phone',
#   'it',
#   'THE',
#   'GO',
#   'I',
#   'functionality'],
#  ['Great',
#   'case',
#   'my',
#   'battery',
#   'life',
#   'Ca',
#   'price',
#   'I',
#   'it',
#   'friend'],
#  ['Great', 'case', 'sturdy', 'battery', 'I', 'my', 'kid', 'he'],
#  ['Bought',
#   'one',
#   'me',
#   'wife',
#   'color',
#   'phone',
#   'wife',
#   'lol.',
#   'Firefighter',
#   'work',
#   'hr',
#   'shift',
#   'me',
#   'anyone',
#   'day'],
#  ['I',
#   'phone',
#   'cases',
#   'I',
#   'THIS',
#   'phone',
#   'case',
#   'What',
#   'find',
#   'STARS'],
#  ['couldnt',
#   'watch',
#   'movies',
#   'htc',
#   'battery',
#   'dying',
#   'phone',
#   'entertainment',
#   'battery',
#   'cases',
#   'fit',
#   'kick',
#   'stand',
#   'teh',
#   'entertainment',
#   'im'],
#  ['product',
#   'I',
#   'kickstand',
#   'back',
#   'power',
#   'indicator',
#   'charge',
#   'pack',
#   'status'],
#  ['HTC', 'battery', 'cases', 'sale', 'price', 'I', 'it', 'stars', 'price'],
#  ['I',
#   'I',
#   'product',
#   'sounding',
#   'reviews',
#   'shills',
#   'PowerBear',
#   'you',
#   'reviews',
#   'case',
#   'you',
#   'none',
#   'them',
#   'purchases',
#   'review',
#   'course',
#   'purchase',
#   'What',
#   'everyone',
#   'who',
#   'product',
#   'it',
#   'Furthermore',
#   'reviewers',
#   'product',
#   'color',
#   'Amazon',
#   'me',
#   'point',
#   'you',
#   'profiles',
#   'reviewers',
#   'you',
#   'they',
#   'reviews',
#   'PowerBear',
#   'products',
#   'reviews',
#   'copies',
#   'paid'],
#  ['doubles',
#   'my',
#   'battery',
#   'life',
#   'I',
#   'my',
#   'charger',
#   'time.For',
#   'price',
#   'deal'],
#  ['Bought',
#   'case',
#   'me',
#   'wife',
#   'shipping',
#   'Came',
#   'colors',
#   'phone',
#   'hours',
#   'I',
#   'kid',
#   'games',
#   'day',
#   'complaints',
#   'problems',
#   'I',
#   'review',
#   'spot',
#   'we',
#   'phones',
#   'colors',
#   'I',
#   '%'],
#  ['I',
#   'my',
#   'phone',
#   'battery',
#   'life',
#   'battery',
#   'case',
#   'I',
#   'battery',
#   'life'],
#  ['Watch-out', 'reviews', 'it', 'name', 'What', 'way', 'item'],
#  ['My',
#   'brother',
#   'HTC',
#   'One',
#   'I',
#   'him',
#   'case',
#   'I',
#   'my',
#   'S4.Super',
#   'sleek',
#   'look',
#   'day',
#   'GPS'],
#  ['color', 'Clips', 'my', 'phone', 'charges', 'me', 'I', 'complain', 'cons'],
#  ['edges', 'screens', 'falls', 'battery', 'case', 'charges', 'me', 'case'],
#  ['fits', 'phone', 'it', 'price', 'product'],
#  ['S5',
#   'phone',
#   'its',
#   'screen',
#   'phone',
#   'battery',
#   'I',
#   'phones',
#   'features',
#   'power',
#   'Great',
#   'buy'],
#  ['money',
#   'It',
#   'my',
#   'phone',
#   'situations',
#   'I',
#   'my',
#   'phone',
#   'it',
#   'my',
#   'battery',
#   'Days',
#   'BRAVO'],
#  ['I',
#   'case',
#   'my',
#   'nephew',
#   'he',
#   'it',
#   'what',
#   'he',
#   'He',
#   'charge',
#   'case',
#   'his',
#   'phone',
#   'it',
#   'thing',
#   'back',
#   'phone',
#   'replacement',
#   'it',
#   'weight'],
#  ['case', 'feels', 'battery', 'hours'],
#  ['I',
#   'case',
#   'choice',
#   'it',
#   'color',
#   'texture',
#   'back',
#   'it',
#   'life',
#   'It',
#   'life',
#   'saver',
#   'market',
#   'time',
#   'phone',
#   'I',
#   'it',
#   'Bought',
#   'me',
#   'my',
#   'brother',
#   'we',
#   'phone',
#   'store'],
#  ['compre',
#   'este',
#   'Case',
#   'hace',
#   'varios',
#   'protege',
#   'el',
#   'celular',
#   'siquiera',
#   'tube',
#   'que',
#   'comprar',
#   'protector',
#   'pantalla',
#   'y',
#   'mi',
#   'cel',
#   'este',
#   'nuevo..'],
#  ['I',
#   'case',
#   'my',
#   'Galaxy',
#   'S2',
#   'version',
#   'store',
#   'cases',
#   'I',
#   'spending',
#   'case',
#   'case',
#   'version',
#   'Galaxy',
#   'S2',
#   'size',
#   'difference',
#   'I',
#   'noise',
#   'microphone',
#   'I',
#   'hole',
#   'case',
#   'it'],
#  ['i',
#   'friend',
#   'amazon',
#   'phone',
#   'cases',
#   'they',
#   'him',
#   'it',
#   'his',
#   'phone',
#   'right'],
#  ['case', 'it', 'changing', 'texture', 'areas', 'buy', 'price'],
#  ['Bought',
#   'my',
#   'AT',
#   'T',
#   'Galaxy',
#   'SII',
#   'case',
#   'its',
#   'fits',
#   'phone',
#   'I',
#   'issues',
#   'buttons',
#   'rubber',
#   'sort',
#   'finish',
#   'It',
#   'your',
#   'pockets',
#   'I',
#   'purchase',
#   'FYI',
#   'AT',
#   'T',
#   'i777',
#   'International',
#   'i9100',
#   'Galaxy',
#   'SII.This',
#   'NOT',
#   'FIT',
#   'Sprint',
#   'T-Mobile',
#   'AT',
#   'T',
#   'Galaxy',
#   'SII',
#   'Skyrocket',
#   'phones',
#   'You'],
#  ['I',
#   'case',
#   'amount',
#   'money',
#   'its',
#   'buy',
#   'cases',
#   'case',
#   'bit',
#   'wouldnt',
#   'hurt.Protects',
#   'phone',
#   'camera',
#   'part',
#   'phone',
#   'surface',
#   'table',
#   'i',
#   'it',
#   'purchase'],
#  ['I',
#   'samsung',
#   'galaxy',
#   's2',
#   'seller',
#   'item',
#   'me',
#   'I',
#   'product',
#   'SGS2',
#   'cut',
#   'outs',
#   'NOT',
#   'cut',
#   'opening',
#   'power',
#   'button',
#   'cut',
#   'reason',
#   'It',
#   'nice',
#   'I',
#   'it',
#   'stars',
#   'opening',
#   'my',
#   'phone'],
#  ['reviews',
#   'rubbery',
#   'case',
#   'exterior',
#   'it',
#   'rubber',
#   'shell',
#   'rubber',
#   'itself',
#   'job',
#   'falls'],
#  ['case',
#   'my',
#   'phone',
#   'tad',
#   'i',
#   'corners',
#   'case',
#   'i',
#   'piece',
#   'case',
#   'cost',
#   'store',
#   'phone',
#   'times',
#   'case',
#   'damage',
#   'phone',
#   'reason',
#   'case',
#   'co-worker',
#   'case',
#   'he',
#   'one',
#   'he',
#   'display',
#   'screen',
#   'his',
#   'phone',
#   'case',
#   'thing',
#   'i',
#   'minutes',
#   'it'],
#  ['skin',
#   'perfect',
#   'my',
#   'SGSII',
#   'phone',
#   'it.It',
#   'quality',
#   'skin',
#   'feeling',
#   'your',
#   'hands.I',
#   'product',
#   'your',
#   'SGSII'],
#  ['I',
#   'style',
#   'case',
#   'otterbox',
#   'case',
#   'mate',
#   'I',
#   'it',
#   'protection',
#   'phone',
#   'brick',
#   'Lightweight'],
#  ['I',
#   'case',
#   'my',
#   'Samsung',
#   'Galaxy',
#   'S2',
#   'I',
#   'touch',
#   'My',
#   'concern',
#   'corners',
#   'it',
#   'it',
#   'scratches',
#   'hit',
#   'I',
#   'it',
#   'stars',
#   'Well',
#   'price',
#   'i',
#   'it'],
#  ['it',
#   'reason',
#   'you',
#   'skin',
#   'case',
#   'amount',
#   'case',
#   'period',
#   'my',
#   'galaxy',
#   's',
#   'II.Di',
#   'buying.But',
#   'it',
#   'day',
#   'deal',
#   'you',
#   'tpu',
#   'case',
#   'your',
#   'phone'],
#  ['Great',
#   'case',
#   'my',
#   'samsung',
#   'galaxy',
#   's2',
#   'order',
#   'it',
#   'my',
#   'phone',
#   'look',
#   'super',
#   'sexy',
#   'me',
#   'you',
#   'order'],
#  ['I', 'reviews', 'I', 'I', 'cause', 'thing', 'Sprint', 'Galaxy', 's2', 'I'],
#  ['cases',
#   'Galaxy',
#   'II',
#   "'s",
#   'Mine',
#   'Sprint',
#   'my',
#   'pnone',
#   'It',
#   'trash',
#   'it',
#   'Otherwise',
#   'I',
#   'it',
#   'case'],
#  ['arrive',
#   'time',
#   'quality',
#   'samsung',
#   'galaxy',
#   'S',
#   'I9100',
#   'fit',
#   'owners',
#   'smartphone'],
#  ['I',
#   'bit',
#   'product',
#   'it',
#   'what',
#   'it',
#   'I',
#   'it',
#   'months',
#   'it',
#   'I',
#   'my',
#   'phone',
#   'point',
#   'I',
#   'it',
#   'quality',
#   'product',
#   "'good",
#   "'",
#   'it'],
#  ['size/design',
#   'Galaxy',
#   'II',
#   'USA',
#   'what',
#   'Asia',
#   'I',
#   'USA',
#   'I',
#   'cover',
#   'Galaxy',
#   'II',
#   'USA',
#   'cover',
#   'speaker',
#   'location',
#   'phone',
#   'I',
#   'cover',
#   'Galaxy',
#   'II',
#   'Asia',
#   'design',
#   'you',
#   'Galaxy',
#   'II',
#   'USA',
#   'USA'],
#  ['It', 'I', 'it', 'It', 'store'],
#  ['I', 'choice', 'thought', 'its', 'customer'],
#  ['my',
#   'purchase',
#   'quality',
#   'shipping',
#   'case',
#   'friction',
#   'grip',
#   'phone',
#   'TPU',
#   'plastic',
#   'material',
#   'case',
#   'oil',
#   'dust',
#   'I',
#   'Otter',
#   'box',
#   'my',
#   'phone',
#   'protection',
#   'BUT',
#   'silicone',
#   'crazy',
#   'pattern',
#   'back',
#   'taste',
#   'people',
#   'it',
#   'me',
#   'it',
#   'flavor',
#   'case',
#   'protection',
#   'sides',
#   'panel',
#   'anyone',
#   'dare',
#   'your',
#   'phone',
#   'floor',
#   'it',
#   'I',
#   'margin',
#   'earphone',
#   'mm',
#   'I',
#   'my',
#   'phone',
#   'case'],
#  ['It', 'quality', 'I', 'color', 'it'],
#  ['case', 'feel', 'design', 'it', 'dust'],
#  ['product', 'It', 'my', 'HTC', 'I', 'complaints'],
#  ['Great',
#   'Grip',
#   'Great',
#   'Style',
#   'Gerat',
#   'Durability',
#   'Great',
#   'PRICE',
#   'SLIM',
#   'FIT',
#   'HTC',
#   'sensation',
#   'purchase',
#   'it',
#   'it',
#   'iPhone',
#   'Too',
#   'HTC'],
#  ['note',
#   'caution',
#   'someone',
#   'who',
#   'Blackberry',
#   'model',
#   'you',
#   'USB',
#   'cable',
#   'you',
#   'you',
#   'cable',
#   'Blackberry',
#   'data',
#   'transfer',
#   'STANDARD',
#   'USB',
#   'cable',
#   'connector',
#   'NOTHING',
#   'cable',
#   'nothing',
#   'justifies',
#   'MSRP',
#   'it',
#   'item',
#   '%',
#   'MSRP',
#   'discount',
#   'it',
#   'paragraph',
#   'you',
#   'you',
#   'USB',
#   'cable.The',
#   'items',
#   'stars',
#   'marketing',
#   'claim',
#   'grade',
#   'custom',
#   'cable',
#   'MSRP.NOTE',
#   'Please',
#   'you',
#   'cable',
#   'connector',
#   'what',
#   'your',
#   'Blackberry'],
#  ['product', 'cable', 'it', 'oem', 'cable'],
#  ['internet',
#   'store',
#   'Gloucester',
#   'MA',
#   'I',
#   'course',
#   'I',
#   'Amazon',
#   'something',
#   'they',
#   'change',
#   'it',
#   'I',
#   'Amazon',
#   'they',
#   'their',
#   'prices',
#   'people',
#   'kind',
#   'money',
#   'wire',
#   'dollars',
#   'I',
#   'what',
#   'I',
#   'my',
#   'dollar',
#   'it',
#   'Thank',
#   'you'],
#  ['I',
#   'cable',
#   'my',
#   'smartphones',
#   'work',
#   'I',
#   'one',
#   'it',
#   'it',
#   'complain'],
#  ['difference',
#   'USB',
#   'cables',
#   'computers',
#   'mine',
#   'USB',
#   'ports',
#   'cables',
#   'data',
#   'I',
#   'cables',
#   'data',
#   'my',
#   'computer',
#   'my',
#   'Blackberry',
#   'Storm',
#   'cable',
#   'my',
#   'USB',
#   'ports'],
#  ['I',
#   'micro',
#   'cable',
#   'it',
#   'it',
#   'I',
#   'my',
#   'Nexus',
#   's',
#   'sprint',
#   'it',
#   'my',
#   'device',
#   'it',
#   'issues',
#   'lag',
#   'my',
#   'computer',
#   'what',
#   'kind',
#   'device',
#   'my',
#   'phone',
#   'car',
#   'mode',
#   'you',
#   'quick',
#   'cable',
#   'charging',
#   'it',
#   'anything',
#   'buck',
#   'end',
#   'cable'],
#  ['I',
#   'cables',
#   'they',
#   'reviews',
#   'I',
#   'people',
#   'cables',
#   'I',
#   'my',
#   'Palm',
#   'Pre',
#   'I',
#   'it',
#   'time',
#   'it',
#   'computer',
#   'Device',
#   'drivers',
#   'it',
#   'cable',
#   'setting',
#   'Charge',
#   'cables',
#   'me',
#   'flaw',
#   'I',
#   'my',
#   'Wife',
#   "'s",
#   'Palm',
#   'Pixi',
#   'computers',
#   'cable',
#   'your',
#   'Palm',
#   'device'],
#  ['phone', 'cord', 'phone', 'computer', 'value', 'price'],
#  ['cable', 'Never', 'issues', 'phone', 'USB', 'connection', 'PC'],
#  ['I',
#   'it',
#   'my',
#   'door',
#   'money',
#   'you',
#   'I',
#   'it',
#   'data',
#   'it',
#   'it',
#   'my',
#   'PC',
#   'work',
#   'my',
#   'Palm',
#   'Pixi',
#   'me',
#   'factory',
#   'cable',
#   'I',
#   'cable',
#   'it',
#   'Do',
#   'you',
#   'cable'],
#  ['inexpensive',
#   'cable',
#   'I',
#   'cable',
#   'I',
#   'one',
#   'stone',
#   'I',
#   'reviews',
#   'cables',
#   'I',
#   'one',
#   'inches',
#   'it',
#   'stone',
#   'I',
#   'cable',
#   'use',
#   'car'],
#  ['cable',
#   'pre',
#   'you',
#   'I',
#   'unit',
#   'plug',
#   'cable',
#   'shipping',
#   'it',
#   'price'],
#  ['wall', 'charger', 'it', 'my', 'I', 'I', 'it', 'you'],
#  ['charger',
#   'trick',
#   'charger',
#   'my',
#   'car',
#   'ignition',
#   'who',
#   'dangling',
#   'cord',
#   'their',
#   'field',
#   'vision',
#   'driving.Have',
#   'T505',
#   'I',
#   'it',
#   'battery',
#   'life',
#   'hours',
#   'usage',
#   'days',
#   'I',
#   'it',
#   'couple',
#   'weeks',
#   'accessory'],
#  ['Motorola',
#   'T505',
#   'AC',
#   'charger',
#   'DC',
#   'charger',
#   'addition',
#   'package',
#   'You',
#   'your',
#   'home',
#   'night'],
#  ['I',
#   'item',
#   'price',
#   'shipping',
#   'I',
#   'wall',
#   'charger',
#   'Motorola',
#   'car',
#   'charger',
#   'their',
#   'wireless',
#   'car',
#   'phone',
#   'speakers',
#   'I',
#   'chance',
#   'price',
#   'shipping',
#   'charger',
#   'market',
#   'chargers',
#   'I',
#   'my',
#   'reader',
#   'PDA',
#   'camera',
#   'etc.',
#   '%',
#   'cost',
#   'I',
#   'my',
#   'Motorola',
#   'speaker',
#   'problems'],
#  ['we',
#   'charging',
#   'cord',
#   't505',
#   'car',
#   'charger',
#   'we',
#   't505',
#   'use',
#   'our',
#   'bluetooth',
#   'phones',
#   'home',
#   'stereo',
#   'cord',
#   'way',
#   'we',
#   'car',
#   'periods',
#   'device',
#   'devices',
#   'we',
#   'charge',
#   'price',
#   'complaints',
#   'receipt',
#   'material',
#   'packaging',
#   'transit',
#   'time'],
#  ['It',
#   'cable',
#   'I',
#   'my',
#   'phone',
#   'it',
#   'data',
#   'datery',
#   'phone',
#   'phoney',
#   'I',
#   'cable',
#   'my',
#   'neck',
#   'bolo',
#   'tie',
#   'people',
#   'me',
#   'I',
#   'jump',
#   'I',
#   'my',
#   'dinner',
#   'plate',
#   'it',
#   'food',
#   'tastes',
#   'cable',
#   'everything',
#   'I'],
#  ['HTC',
#   'cable',
#   'it',
#   'Blackberry',
#   'logo',
#   'it',
#   'bulk',
#   'packaging',
#   'label',
#   'Blackberry',
#   'it',
#   'OEM',
#   'micro',
#   'cable',
#   'none',
#   'device',
#   'I',
#   'it',
#   'into.While',
#   'I',
#   'it',
#   'cables',
#   'I',
#   'it',
#   'OEM',
#   'cable',
#   'it',
#   'I',
#   'it.The',
#   'cable',
#   'bit',
#   'result',
#   'so.It',
#   'cable',
#   'picture',
#   'product',
#   'usb',
#   'cable',
#   'bit',
#   'product',
#   'cable'],
#  ['cable', 'device', 'what', 'I', 'error', 'message', 'it'],
#  ['I',
#   'HTC',
#   'accessories',
#   'HTC',
#   'phones',
#   'luck',
#   'aftermarket',
#   'products'],
#  ['I',
#   'review',
#   'item',
#   'it',
#   'complains',
#   'it',
#   'EXACT',
#   'phone',
#   'I',
#   'it',
#   'I',
#   'it',
#   'people',
#   'it',
#   'I',
#   'I',
#   'It',
#   'what',
#   'I',
#   'I',
#   'I',
#   'my',
#   'car',
#   'work',
#   'change',
#   'buy',
#   'me',
#   'I',
#   'my',
#   'battery'],
#  ['I',
#   'price',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'my',
#   'phone',
#   'it',
#   'I',
#   'day',
#   'it',
#   'charge'],
#  ['i',
#   'spare',
#   'cord',
#   'i',
#   'cord',
#   'my',
#   'car',
#   'charger',
#   'tired',
#   'track',
#   'i',
#   'it',
#   'cord',
#   'wall',
#   'pc',
#   'phone',
#   'wont',
#   'stay',
#   'pc',
#   'files',
#   'anything',
#   'you',
#   'cord',
#   'wall',
#   'cord',
#   'you',
#   'it',
#   'pc'],
#  ['I',
#   'cord',
#   'my',
#   'phone',
#   'my',
#   'pc',
#   'work',
#   'it',
#   'fast',
#   'charges',
#   'it',
#   'less'],
#  ['product', 'value', 'price', 'it', 'it', 'you', 'it', 'you', 'cords'],
#  ['manufacturing', 'quality', 'connector', 'fit', 'my', 'phone', 'I'],
#  ['cable',
#   'works',
#   'my',
#   'verizon',
#   'Galaxy',
#   'S4',
#   'it',
#   'data',
#   'fine.However',
#   'connector',
#   'tip',
#   'phone',
#   'side',
#   'it',
#   'you',
#   'cases'],
#  ['It',
#   'what',
#   'it',
#   'charging',
#   'sync',
#   'cord',
#   'It',
#   'phone',
#   'data',
#   'phone',
#   'computer'],
#  ['cable', 'it', 'Samsung', 'Galaxy', 'S4', 'It', 'plug'],
#  ['It', 'value', 'price', 'stores', 'it'],
#  ['works', 'it', 'backup', 'cables', 'my'],
#  ['I',
#   'chargers',
#   'my',
#   'Samsung',
#   'phone',
#   'amazon',
#   'quality',
#   'them',
#   'I',
#   'chargers',
#   'I',
#   'they',
#   'months',
#   'money',
#   'quality'],
#  ['I',
#   'my',
#   'Samsung',
#   'Galaxy',
#   'S2',
#   'it',
#   'ALWAYS',
#   'phone',
#   'whenever',
#   'phone',
#   'it',
#   'surface',
#   'it',
#   'its',
#   'way',
#   'phone',
#   'I',
#   'USB',
#   'cord',
#   'I'],
#  ['USB',
#   'cable',
#   'my',
#   'Samsung',
#   'smartphone',
#   'my',
#   'computer',
#   'Works',
#   'fits',
#   'my',
#   'needs',
#   'expectations'],
#  ['it', 'time', 'you', 'chargers', 'thanks'],
#  ['they', 'I', 'them', 'problems'],
#  ['It', 'what', 'I', 'it', 'gauge', 'wire'],
#  ['you', 'your', 'phone', 'you', 'data', 'boy', 'cable'],
#  ['Works',
#   'IF',
#   'you',
#   'phone',
#   'you',
#   'phone',
#   'plug',
#   'its',
#   'way',
#   'minutes',
#   'fit',
#   'Note',
#   'cord',
#   'phone',
#   'plugs',
#   'smoothly',
#   'my',
#   'cord',
#   'phone'],
#  ['they',
#   'they',
#   'devices',
#   'They',
#   'time',
#   'ad',
#   'they',
#   'Samsung',
#   'Galaxy',
#   'devices',
#   'It',
#   'work',
#   'my',
#   'S4',
#   'They',
#   'charger',
#   'd',
#   'one'],
#  ['charger', 'i', 'it', 'charger', 'it', 'cord', 'my', 'phone', 'charge'],
#  ['It', 'It', 'my', 'phone', 'it', 'it', 'problems', 'charger'],
#  ['divice', 'I', 'order', 'months', 'family', 'friends', 'who', 'mine', 'it'],
#  ['charger',
#   'it',
#   'it',
#   'minutes',
#   'I',
#   '%',
#   'my',
#   'battery',
#   'I',
#   'it',
#   'my',
#   'battery',
#   'I',
#   'it',
#   'it'],
#  ['I', 'day', 'it', 'my', 'phone', 'middle', 'trip'],
#  ['I',
#   'charger',
#   'cord',
#   'time',
#   'it',
#   'Item',
#   'seller',
#   'cord',
#   'snap',
#   'I',
#   'it',
#   'It',
#   'length',
#   'I',
#   'it',
#   'way',
#   'my',
#   'phone',
#   'cord',
#   'I',
#   'it'],
#  ['It',
#   'it',
#   'It',
#   'my',
#   'Galaxy',
#   'fine',
#   'cord',
#   'Mine',
#   'spring',
#   'Cheap',
#   'I',
#   'shipping',
#   'It',
#   'I',
#   'matters'],
#  ['price',
#   'I',
#   'these.It',
#   'purpose',
#   'months',
#   'them',
#   'working.that',
#   '%',
#   'rate',
#   'I',
#   'what',
#   'life',
#   'charger'],
#  ['it', 'charger', 'price', 'I', 'they', 'price', 'I', 'it', 'deal'],
#  ['it',
#   'car',
#   'car',
#   'person',
#   'case',
#   'backpack',
#   'travel',
#   'cord',
#   'hanging',
#   'wrapping'],
#  ['charger', 'It', 'value', 'they', 'stores', 'it'],
#  ['plug',
#   'fits',
#   'it',
#   'my',
#   'Captivate',
#   'it',
#   'snug',
#   '-ness',
#   'charger',
#   'anything',
#   'Plain',
#   "'",
#   'I',
#   'it',
#   'package',
#   'time',
#   'I',
#   'cord',
#   'it',
#   'inches',
#   'button',
#   'it',
#   'it',
#   'inches',
#   'it',
#   'I',
#   'it',
#   'inches',
#   'it',
#   'Bottom',
#   'line',
#   'it',
#   'it',
#   'charger',
#   'it',
#   'itself',
#   'retract',
#   'button',
#   'it',
#   'minutes',
#   'plug',
#   'inches',
#   'cable',
#   'charger',
#   'I',
#   'cable',
#   'inches',
#   'length',
#   'reason',
#   'I',
#   'retractability',
#   'I',
#   'cables',
#   'refund',
#   'item'],
#  ['I', 'years', 'it', 'NOW', 'I', 'it', 'button', 'it', 'it'],
#  ['charger',
#   'cord',
#   'cup',
#   'holder',
#   'my',
#   'truck',
#   'i',
#   'my',
#   'phone',
#   'side',
#   'welps',
#   'my',
#   'arm',
#   'cord',
#   'haha'],
#  ['reviews',
#   'Price',
#   'I',
#   'extras',
#   'case',
#   'Quality',
#   'Cord',
#   'comments',
#   'Love',
#   'cords',
#   'car'],
#  ['I', 'feature', 'it', 'I', 'job', 'thick', 'device', 'product'],
#  ['my',
#   'Captivate',
#   'products',
#   'it',
#   'connection',
#   'phone',
#   'USB',
#   'end',
#   'problem'],
#  ['Item', 'Item', 'my', 'car', 'phone', 'Item', 'advertise'],
#  ['Great', 'I', 'it', 'my', 'GF', 'she', 'it'],
#  ['charger', 'it', 'lot', 'Sprint', 'store'],
#  ['I',
#   'cord',
#   'changer',
#   'I',
#   'night',
#   'stand',
#   'table',
#   'I',
#   'it',
#   'I',
#   'fan',
#   'it',
#   'charge',
#   'it',
#   'stops',
#   'times',
#   'it'],
#  ['charger', 'travel', 'back', 'your', 'house', 'I', 'it'],
#  ['I', 'item', 'I', 'it', 'it', 'gift', 'I', 'star', 'rating', 'product'],
#  ['Phone',
#   'charger',
#   'it',
#   'phone',
#   'phone',
#   'it',
#   'battery',
#   'it',
#   'battery',
#   'percentage.I',
#   'charger',
#   'phone',
#   'I',
#   'I',
#   'reviewers',
#   'battery',
#   'phone',
#   'I',
#   'too.I',
#   'charger.The',
#   'charger',
#   'my',
#   'blackberry'],
#  ['I', 'cord', 'I', 'month'],
#  ['It', 'It', 'cord', 'one', 'I', 'phone', 'I', 'item'],
#  ['i', 'charger', 'my', 'wallit', 'half', 'Lesson', 'things'],
#  ['power',
#   'cord',
#   'replacement',
#   'use',
#   'cord',
#   'your',
#   'phone',
#   'use',
#   'I',
#   'standard',
#   'cord',
#   'your',
#   'phone',
#   'data',
#   'cable',
#   'power',
#   'plug',
#   'end',
#   'I',
#   'phone',
#   'twist',
#   'tug',
#   'line',
#   'cable',
#   'dc',
#   'power',
#   'supply',
#   'I',
#   'data',
#   'cable',
#   'time',
#   'battery',
#   'Phone',
#   'companies',
#   'phones',
#   'power',
#   'cable',
#   'data',
#   'cable',
#   'end',
#   'you',
#   'yourself',
#   'power',
#   'cable',
#   'price-wise',
#   'Yep',
#   'Oh',
#   'light',
#   'you',
#   'it',
#   'wall',
#   'your',
#   'phone',
#   'it',
#   'you',
#   'sleepers',
#   'room',
#   'you',
#   'yourself',
#   'piece',
#   'tape',
#   'light',
#   'it',
#   'you'],
#  ['we', 'it', 'month', 'it', 'cord', 'it', 'you', 'phone'],
#  ['it', 'it', 'i', 'chargers', 'wire', 'its', 'well', 'im', 'its', 'amount'],
#  ['Thanks',
#   'delivery',
#   'time',
#   'it',
#   'quality',
#   'note',
#   'pad',
#   'Mom',
#   'it',
#   'it',
#   'replacement',
#   'gift',
#   'brand',
#   'company'],
#  ['I', 'cord', 'It', 'my', 'phone', 'you', 'it', 'Thanks'],
#  ['Paid',
#   'charger',
#   'Shipping',
#   'Handling',
#   '..Yeah',
#   'I',
#   'shipping',
#   'handling',
#   'charger',
#   'I',
#   'charger',
#   'fit',
#   'nice',
#   'snug',
#   'I',
#   'my',
#   'phone',
#   'my',
#   'desk',
#   'my',
#   'home',
#   'office',
#   'my',
#   'computer',
#   'work',
#   '..which',
#   'day',
#   'job',
#   'huh',
#   'Wow',
#   'I',
#   'I',
#   'reviews',
#   'living',
#   'I',
#   'price',
#   'savings',
#   'retailers',
#   'phones',
#   'charge',
#   'Ms_Thrifty',
#   'it',
#   'Stay',
#   'reviews',
#   'Oh',
#   'I'],
#  ['stars', 'cord', 'Works', 'Charges', 'phone'],
#  ['Its', 'charger', 'it', 'It', 'mail', 'I'],
#  ['U', 'Bought', 'spare', 'purse', 'home', 'work', 'I', 'it'],
#  ['Product',
#   'cord',
#   'factory',
#   'cord',
#   'day',
#   'I',
#   'what',
#   'price',
#   'I',
#   'perfection',
#   'Sellers',
#   'defense',
#   'I',
#   'them..it',
#   'my',
#   'fault',
#   'I',
#   'Sorry'],
#  ['my',
#   'office',
#   'work',
#   'boost',
#   'Nothing',
#   'charger',
#   'what',
#   'its',
#   'ment'],
#  ['Bought',
#   'gift',
#   'my',
#   'he',
#   'it',
#   'job',
#   'Would',
#   'product',
#   'customers.Thank',
#   'you'],
#  ['you',
#   'your',
#   'tooth',
#   'you',
#   'hands',
#   'wheel',
#   'your',
#   'BT',
#   'battery',
#   'charge',
#   'I',
#   'length',
#   'cord',
#   '.I',
#   'plug-in',
#   'charger',
#   'me'],
#  ['I', 'car', 'charger', 'months', 'Nice', 'cord', 'It', 'push', 'button'],
#  ['it', 'one.The', 'end', 'Iphone', 'it', 'it'],
#  ['I', 'my', 'wife', 'issue.I', 'x50', 'headset', 'she', 'voyage', 'it'],
#  ['THIS',
#   'BAD',
#   'CHARGER',
#   'IT',
#   'DOES',
#   'NOT',
#   'PROPERLY',
#   'IT',
#   'HAS',
#   'A',
#   'REALLY',
#   'BAD',
#   'SHORTAGE',
#   'I'],
#  ['works', 'my', 'Plantronics', 'BT', 'i', 'cord', 'it', 'cord', 'way', 'use'],
#  [],
#  ['I',
#   'bit',
#   'headset',
#   'condition',
#   'price',
#   'tag',
#   'headset',
#   'I',
#   'sorts',
#   'shortcomings',
#   'it',
#   'I',
#   'condition',
#   'headset',
#   'It',
#   'scratches',
#   'labeling',
#   'It',
#   'brand',
#   'yeah',
#   'it'],
#  ['I',
#   'headset',
#   'head',
#   'band',
#   'ear',
#   'piece',
#   'quality',
#   'ability',
#   'mic',
#   'reason',
#   'I',
#   'mute',
#   'switch',
#   'place',
#   'clip',
#   'your',
#   'shirt',
#   'reason',
#   'I',
#   'stars',
#   'I',
#   'lot',
#   'people',
#   'me',
#   'I',
#   'it',
#   'I',
#   'it',
#   'volume',
#   'feature',
#   'my',
#   'mouth',
#   'purchase',
#   'money'],
#  ['I',
#   'years',
#   'I',
#   'it',
#   'mic',
#   'my',
#   'voice',
#   'I',
#   'complaints',
#   'people',
#   'me',
#   'ear-pad',
#   'I',
#   'I',
#   'part',
#   'amplifier',
#   'I',
#   'distortion',
#   'sound',
#   'my',
#   'cell',
#   'phone',
#   'I',
#   'output',
#   'cell',
#   'phone',
#   'itself',
#   'amplifier',
#   'headset',
#   'I',
#   'sound',
#   'distortion',
#   'I',
#   'anything',
#   'my',
#   'hand',
#   'conversation'],
#  ['type',
#   'headset',
#   'I',
#   'work',
#   'day',
#   'I',
#   'home',
#   'I',
#   'things',
#   'my',
#   'ear',
#   'quality',
#   'keeps',
#   'everything',
#   'it',
#   'I',
#   'it',
#   'hours',
#   'pain',
#   'irritation',
#   'hair',
#   'It',
#   'leatherette',
#   'cup',
#   'speaker',
#   'I',
#   'it',
#   'it',
#   'it',
#   'It',
#   'hook',
#   'type',
#   'I',
#   'volume',
#   'control',
#   'mute',
#   'bit',
#   'Great',
#   'quality'],
#  ['headset',
#   'I',
#   'quality',
#   'price',
#   'it',
#   'my',
#   'Samsung',
#   'Galaxy',
#   'I',
#   'issue',
#   'mm',
#   'adapter',
#   'I',
#   'it',
#   'my',
#   'cordless',
#   'phone',
#   'you',
#   'call',
#   'cell',
#   'phone',
#   'what',
#   'I',
#   'headset',
#   'sound',
#   'quality'],
#  ['I', 'its', 'durability', 'quality', 'volume'],
#  ['quality',
#   'headset',
#   'quality',
#   'piece',
#   'Plantronics',
#   'quality',
#   'jack',
#   'it',
#   'phones',
#   'headphone',
#   'jack',
#   'my',
#   'Blackberry',
#   'it',
#   'Pearl',
#   'bonus',
#   'I',
#   'it',
#   'my',
#   'XBOX',
#   'controllers',
#   'messenger',
#   'keyboard',
#   'online',
#   'gaming',
#   'people',
#   'I',
#   'headset',
#   'wireless',
#   'XBOX',
#   'controller',
#   'mic',
#   'my',
#   'mouth',
#   'fixes',
#   'sensitivity',
#   'switch',
#   'plug',
#   'difference',
#   'people',
#   'end',
#   'conversation.It',
#   "'s",
#   'years',
#   'bags',
#   'It',
#   'wireless',
#   'headsets',
#   'etc',
#   'it',
#   'batteries',
#   'interference',
#   'I',
#   'it'],
#  ['I',
#   'product',
#   'I',
#   'I',
#   'adaptor',
#   'I',
#   'issue',
#   'my',
#   'fault',
#   'company',
#   'customer',
#   'service'],
#  ['reviews',
#   'my',
#   'Nexus',
#   'S',
#   'cell',
#   'phone',
#   'person',
#   'end',
#   'quality',
#   'sound',
#   'I',
#   'headset',
#   'my',
#   'cell',
#   'they',
#   'problem',
#   'problem',
#   'headset.Also',
#   'FYI',
#   'bag',
#   'instructions',
#   'problem',
#   'me',
#   'me',
#   'quality'],
#  ['sound',
#   'my',
#   'voice',
#   'parties',
#   'volume',
#   'switch',
#   'mute',
#   'slider',
#   'work',
#   'it',
#   'time'],
#  ['I',
#   'headsets',
#   'years',
#   'them',
#   'friends',
#   'associates',
#   'I',
#   'them',
#   'gifts',
#   'headset',
#   'You',
#   'people',
#   'who',
#   'pains',
#   'their',
#   'neck',
#   'phone',
#   'their',
#   'head',
#   'headsets',
#   'I',
#   'them',
#   'variety',
#   'cordless',
#   'cell',
#   'phones',
#   'you',
#   'socket',
#   'you',
#   'business',
#   'Audio',
#   'reception',
#   'me',
#   'hearing',
#   'loss',
#   'microphones',
#   'break',
#   'I',
#   'it',
#   'travel',
#   'case',
#   'I',
#   'regard',
#   'abuse',
#   'well.All',
#   'value.Jerry'],
#  ['I',
#   'headsets',
#   'others',
#   'I',
#   'volume',
#   'earpiece',
#   'quality',
#   'microphone',
#   'I',
#   'Panasonic',
#   'TCA60',
#   'ends',
#   'It',
#   'nothing',
#   'fancy',
#   'volume',
#   'control',
#   'mute',
#   'who',
#   'you',
#   'thing',
#   'your',
#   'phone',
#   'Price',
#   'quality',
#   'I',
#   'product'],
# ...
#   'case',
#   'holder',
#   'flip',
#   'case',
#   'hole',
#   'back',
#   'case',
#   'removal',
#   'phone',
#   'button',
#   'closure',
#   'cases',
#   'con',
#   'Speaker',
#   'hole',
#   'front',
#   'case',
#   'phone.Howeva',
#   'Might',
#   'color'],
#  ['Bought',
#   'my',
#   'girlfriend',
#   "'s",
#   's3',
#   'she',
#   'it',
#   'lanyard',
#   'it',
#   'case',
#   'phone',
#   'Fitment',
#   'slick',
#   'outer',
#   'sheen',
#   'it',
#   'its',
#   'marks/scratches',
#   'purse',
#   'pens',
#   'anything',
#   'thing',
#   'I',
#   'sellers',
#   'page',
#   'case',
#   'snap',
#   'It',
#   'they',
#   'picture',
#   'you',
#   'kind',
#   'see',
#   'it',
#   'side',
#   'problem',
#   'it',
#   'magnet',
#   'drawbacks',
#   'you',
#   'cover',
#   'while',
#   'it',
#   'smudge',
#   'marks',
#   'phone',
#   'card',
#   'pockets',
#   'use',
#   'phone',
#   'case',
#   'it',
#   'cases',
#   'I',
#   'problem'],
#  ['product',
#   'material',
#   'leather',
#   'I',
#   'something',
#   'feel',
#   'it',
#   'one',
#   'look'],
#  ['I', 'my', 'Galaxy', 'S4', 'case', 'it', 'It', 'plastic', 'casing', 'phone'],
#  ['I',
#   'CASE',
#   'VERY',
#   'MUCH',
#   '=',
#   'BUT',
#   'I',
#   'THE',
#   'PHONE',
#   '=',
#   'SO',
#   'THE',
#   'NEW',
#   'BUYER',
#   'THAT',
#   'IT',
#   'FROM',
#   'ME',
#   'AND',
#   'THE',
#   'CASE'],
#  ['case',
#   'my',
#   'phone',
#   'phone',
#   'case',
#   'it',
#   'protection',
#   'drop',
#   'slip',
#   'hand',
#   'I',
#   'case',
#   'patent',
#   'leather',
#   'it',
#   'case'],
#  ['Its',
#   'wristlet',
#   'thread',
#   'You',
#   'your',
#   'phone',
#   'plastic',
#   'backing',
#   'purse',
#   'Money',
#   'part',
#   'length',
#   'cash',
#   'Id',
#   'cash',
#   'compartment',
#   'thing',
#   'I',
#   'my',
#   'purchase',
#   'Id',
#   'purchase',
#   'product',
#   'wristlet',
#   'breaks',
#   'it',
#   'your',
#   'product',
#   'Buyer',
#   'Update',
#   'I',
#   'day',
#   'I',
#   'my',
#   'phone',
#   'kind',
#   'stuck',
#   'it',
#   'I',
#   'it',
#   'my',
#   'note',
#   'screen',
#   'pieces',
#   'your',
#   'phone',
#   'protection',
#   'phone'],
#  ['nothing',
#   'product',
#   'my',
#   'taste',
#   'it',
#   'bit',
#   'I',
#   'Quality',
#   'complaints'],
#  ['case',
#   'it',
#   'necessities',
#   'credit',
#   'card',
#   'id',
#   'cash',
#   'it',
#   'plastic',
#   'minutes',
#   'I',
#   'it',
#   'me',
#   'case',
#   'It',
#   'it'],
#  ['case', 'what', 'my', 'girlfreind', 'forever', 'pockets', 'cover', 'thanks'],
#  ['I',
#   'case',
#   'lot',
#   'I',
#   'price',
#   'it',
#   'TPU',
#   'I',
#   'I',
#   'feeling',
#   'lot',
#   'Spigen',
#   'Neo-Hybrid',
#   'I',
#   'months',
#   'it',
#   'I',
#   'my',
#   'charging',
#   'headphone',
#   'devices',
#   'Spigen',
#   'It',
#   'case',
#   'bulky',
#   'it',
#   'It',
#   'my',
#   'hands',
#   'I',
#   'case',
#   'I',
#   'it'],
#  ['i',
#   'style',
#   'wrist',
#   'band',
#   'clip',
#   'credit',
#   'cards',
#   'its',
#   'hard',
#   'phone',
#   'stays',
#   'ok',
#   'phone'],
#  ['It', 'patent', 'case', 'phone', 'occasions', 'case'],
#  ['it',
#   'my',
#   'mom',
#   'her',
#   'purse',
#   'she',
#   'it',
#   'She',
#   'it',
#   'her',
#   'signature',
#   'case',
#   'becasue',
#   'quality'],
#  ['Looks',
#   'feels',
#   'plastic',
#   'magnet',
#   'picture',
#   'person',
#   'couple',
#   'weeks'],
#  ['It', 'case', 'Well', 'GREAT', 'color', 'I', 'size', 'it'],
#  ['cover',
#   'she',
#   'her',
#   'Samsung',
#   'Galaxy',
#   'Note',
#   'my',
#   'wife',
#   'BoxWave',
#   'She',
#   'compartments',
#   'her',
#   'ID',
#   'credit',
#   'card',
#   'money',
#   'fit',
#   'problems',
#   'pictures',
#   'She',
#   'strap',
#   'case',
#   "'s",
#   'flexibility'],
#  ['I',
#   'my',
#   'daughter',
#   'her',
#   'vacation',
#   'cruise',
#   'clasp',
#   'her',
#   'room',
#   'card',
#   'credit',
#   'card',
#   'Kind',
#   'defeats',
#   'purpose',
#   'clutch',
#   'It',
#   'you',
#   'your',
#   'drivers',
#   'phone',
#   'cash',
#   'people',
#   'cash',
#   'credit',
#   'bank',
#   'card'],
#  ['BoxWave',
#   'protection',
#   'your',
#   'Samsung',
#   'Galaxy',
#   'Note',
#   'bulk',
#   'LiviTech',
#   'Defender',
#   'Double',
#   'Layer',
#   'Hybrid',
#   'Hard',
#   'Case',
#   'I',
#   'Samsung',
#   'OEM',
#   'Case',
#   'them'],
#  ['case',
#   'Note',
#   'I',
#   'cover',
#   'holster',
#   'I',
#   'I',
#   'REIKO',
#   'case',
#   'They',
#   'you',
#   'it',
#   'Note',
#   'REIKO',
#   'it',
#   'fit',
#   'I',
#   'BoxWave',
#   'my',
#   'decision',
#   'I',
#   'Note',
#   'my',
#   'pocket',
#   'phone',
#   'my',
#   'pants',
#   'pros',
#   'case',
#   'it',
#   'Note',
#   'look',
#   'rubbery',
#   'feel',
#   'it',
#   'phone',
#   'feel',
#   'my',
#   'hand',
#   'rubbery',
#   'feel',
#   'it',
#   'my',
#   'pocket',
#   'I',
#   'con',
#   'BoxWave',
#   'Tuxedo',
#   'Suitup',
#   'case',
#   'it',
#   'its',
#   'glossiness',
#   'it',
#   'fingerprints',
#   'they',
#   'summary',
#   'I',
#   'order',
#   'cases'],
#  ['I',
#   'item',
#   'Dec.',
#   'Been',
#   'it',
#   'I',
#   'it',
#   'it',
#   'its',
#   'job',
#   'It',
#   'weight',
#   'bulk',
#   'phone',
#   'it',
#   'Well',
#   'money',
#   'I',
#   'colors'],
#  ['My',
#   'TPU',
#   'case',
#   'Offers',
#   'protection',
#   'grip',
#   'it',
#   'I',
#   'couple',
#   'cards',
#   'bills',
#   'phone',
#   'case'],
#  ['Adds',
#   'bulk',
#   'my',
#   'phone',
#   'hence',
#   'I',
#   'case',
#   'pictures',
#   'site',
#   'buttons',
#   'your',
#   'phone',
#   'areas',
#   'case',
#   'power',
#   'button',
#   'volume',
#   'rocker',
#   'plastic',
#   'my',
#   'opinion',
#   'Makes',
#   'it',
#   'buttons',
#   'Might',
#   'amount',
#   'protection',
#   'their',
#   'phone'],
#  ['case',
#   'thicker',
#   'my',
#   'TPU',
#   'slim',
#   'case',
#   'I',
#   'firmness',
#   'material',
#   'gaps',
#   'rubber',
#   'my',
#   'case',
#   'Fit',
#   'feels',
#   'hand'],
#  ['Case',
#   'fit',
#   'feel',
#   'size',
#   'buttons',
#   'me',
#   'volume',
#   'on/off',
#   'feel',
#   'Nice',
#   'case',
#   'build',
#   'fit',
#   'Slides',
#   'issue'],
#  ['case', 'tackle', 'touch', 'it', 'phone.Fits', 'thank', 'you'],
#  ['Fits',
#   'offers',
#   'protection',
#   'phone',
#   'grip',
#   'price',
#   'I',
#   'order',
#   'case'],
#  ['thing',
#   'I',
#   'case',
#   'I',
#   'Box',
#   'Wave',
#   'It',
#   'it',
#   'it',
#   'thing',
#   'my',
#   'book',
#   'case',
#   'hand',
#   'feels',
#   'controls',
#   'everything',
#   'my',
#   'Galaxy',
#   'Note',
#   'case',
#   'it',
#   'thing',
#   'I',
#   'holster',
#   'I',
#   'holsters',
#   'my',
#   'phone',
#   'my',
#   'belt',
#   'Well',
#   'I',
#   'holster',
#   'my',
#   'purchases',
#   'my',
#   'phone',
#   'it',
#   'Box',
#   'Wave',
#   'glove',
#   'It',
#   'rubber',
#   'plastic',
#   'cases',
#   'Amazon',
#   'I',
#   'name',
#   'I',
#   'I',
#   'review',
#   'you',
#   'order',
#   'case',
#   'holster',
#   'combo',
#   'holster',
#   'I',
#   'chance',
#   'name',
#   'case',
#   'holster',
#   'it',
#   'Rhino',
#   'brand',
#   'ones',
#   'I',
#   'Black',
#   'Rhino',
#   'I',
#   'cases',
#   'holster',
#   'fit',
#   'Box',
#   'Wave',
#   'case'],
#  ['Bought',
#   'I',
#   'my',
#   'wife',
#   'year',
#   'it',
#   'way',
#   'it',
#   'it',
#   'glove',
#   'stability',
#   'side',
#   'phone',
#   'function'],
#  ['I',
#   'cases',
#   'cellphones',
#   'case',
#   'me',
#   'review',
#   'THE',
#   'case',
#   'I',
#   'It',
#   'you',
#   'it',
#   'skin',
#   'phone',
#   'fact',
#   'it',
#   'lot',
#   'bulk',
#   'feels',
#   'it',
#   'it',
#   'case',
#   'price',
#   'I',
#   'they',
#   'case',
#   'phone',
#   'It',
#   'my',
#   'case',
#   'Please',
#   'HTC'],
#  ['I',
#   'fan',
#   'TPU',
#   'cases',
#   'silicone',
#   'ones',
#   'difference',
#   'case',
#   'you',
#   'reader',
#   'TPU',
#   'LIGHT',
#   'YEARS',
#   'lot',
#   'TPU',
#   'cases',
#   'anything',
#   'TPU',
#   'Rather',
#   'it',
#   'they',
#   'cheaply',
#   'sort',
#   'thing.This',
#   'case',
#   'precision',
#   'cut',
#   'It',
#   'hole',
#   'it',
#   'beneath',
#   'camera',
#   'flash',
#   'speaker',
#   'holes',
#   'earphone',
#   'jack',
#   'course',
#   'stylus',
#   'Note',
#   'holes',
#   'power',
#   'button',
#   'volume',
#   'rocker',
#   'TRUST',
#   'ME',
#   'way',
#   'it',
#   'SHOULD',
#   'TPU',
#   'cases',
#   'cutouts',
#   'power',
#   'button',
#   'volume',
#   'rockers',
#   'mistake',
#   'you',
#   'computer',
#   'mouse',
#   'you',
#   'ones',
#   'rubber',
#   'ball',
#   'centerhold',
#   'bottom',
#   'you',
#   'up',
#   'you',
#   'kinda',
#   "'",
#   'weird',
#   'stuff',
#   'you',
#   'rollers',
#   'whatnot',
#   'stuff',
#   'oil',
#   'cells',
#   'dust',
#   'hair',
#   'lint',
#   'mouse',
#   'pad',
#   'godknows',
#   'what',
#   'It',
#   'anything',
#   'hardware',
#   'buttons',
#   'smartphone',
#   'stuff',
#   'buttons',
#   'phones',
#   'their',
#   'screens',
#   'ones',
#   'people',
#   'power',
#   'button',
#   'boot',
#   'TPU',
#   'cover',
#   'power',
#   'button',
#   'volume',
#   'rocker',
#   'problem',
#   'course',
#   'HOME',
#   'key',
#   'you',
#   'YouTube',
#   'you',
#   'examples',
#   'phones',
#   'their',
#   'owners',
#   'their',
#   'HOME',
#   'keys',
#   'cause',
#   'behavior',
#   'fact',
#   'time',
#   'HOME',
#   'key',
#   'gunked-up',
#   'body',
#   'oil',
#   'dust',
#   'hair',
#   'you',
#   'picture.There',
#   'lot',
#   'we',
#   'HOME',
#   'key',
#   'problem',
#   'it',
#   'capacitive',
#   'glass',
#   'we',
#   'crap',
#   'our',
#   'power',
#   'buttons',
#   'volume',
#   'rockers',
#   'TPU',
#   'cases',
#   'them',
#   'one',
#   'It',
#   'buttons',
#   'TPU',
#   'cases',
#   'sort',
#   'bulge',
#   'bit',
#   'texture',
#   'it',
#   'case',
#   'case',
#   'reason',
#   'people',
#   'I',
#   'its',
#   'sides',
#   'face',
#   'phone',
#   'bezel',
#   'glass',
#   'screen',
#   'It',
#   'TPU',
#   'cases',
#   'Note',
#   'II',
#   'its',
#   'glass',
#   'screen',
#   'phone',
#   'phones',
#   'piece',
#   'glass',
#   'their',
#   'screens',
#   'metal',
#   'bezel',
#   'case',
#   'contact',
#   'glass',
#   "'s",
#   'edge',
#   "all-'round",
#   'top',
#   'bezel',
#   'plane',
#   'glass',
#   'screen',
#   'you',
#   'phone',
#   'its',
#   'glass',
#   'screen',
#   'table',
#   'glass',
#   'itself',
#   'it',
#   'table',
#   'bezel',
#   'edge',
#   'it',
#   'millimeter',
#   'table',
#   "'s",
#   'surface.Well',
#   'Note',
#   'II',
#   "'s",
#   'glass',
#   'it',
#   'its',
#   'back',
#   'bezel',
#   'edge',
#   'case',
#   'fact',
#   'edge',
#   'Note',
#   'II',
#   "'s",
#   'glass',
#   'seesm',
#   'case',
#   "'s",
#   'bezel',
#   'you',
#   'Note',
#   'II',
#   'its',
#   'face',
#   'its',
#   'glass',
#   'it',
#   'glass',
#   'table',
#   'bit',
#   'regard',
#   'protectors',
#   'maker',
#   'them',
#   'REALOOK',
#   'versions',
#   'Note',
#   'II',
#   'one',
#   'part',
#   'Note',
#   'II',
#   "'s",
#   'screen',
#   'amount',
#   'glass',
#   'edge',
#   'screen',
#   'protector',
#   'glass',
#   'edge',
#   'they',
#   'REALOOK',
#   'screen',
#   'protector',
#   'Note',
#   'II',
#   'edge',
#   'Note',
#   'II',
#   "'s",
#   'glass',
#   'hang',
#   'it',
#   'protector',
#   "'s",
#   'edge',
#   'case',
#   "'s",
#   'bezel',
#   'it',
#   'COMPLETELY',
#   'glass',
#   'its',
#   'edge.With',
#   'TPU',
#   'cases',
#   'TPU',
#   'sides',
#   'face',
#   'glass',
#   'screen',
#   'protectors',
#   'millimeter',
#   'screen',
#   'protector',
#   'edge',
#   'bezel',
#   'TPU',
#   'case',
#   'edge',
#   'it',
#   'screen',
#   'protector',
#   'glass',
#   'REALOOK',
#   'style',
#   'screen',
#   'protector',
#   'edge',
#   'kind',
#   'kind',
#   'TPU',
#   'case',
#   'edges',
#   'corners',
#   'screen',
#   'protector',
#   'BoxWave',
#   'Tuxedo',
#   'SuitUp',
#   'case',
#   'its',
#   'edge',
#   'glass',
#   'plane',
#   'glass',
#   'phone',
#   'its',
#   'face',
#   'its',
#   'glass',
#   'sreen',
#   'glass',
#   'it',
#   'millimeter',
#   'table',
#   'desk',
#   'it',
#   'respects',
#   'edge',
#   'Note',
#   'II',
#   "'s",
#   'glass',
#   'it',
#   'REALOOK',
#   'screen',
#   'protector',
#   "'s",
#   'edges',
#   'corners',
#   'beautiful.This',
#   'TPU',
#   'case',
#   'others',
#   'kind',
#   'you',
#   'you',
#   'protector',
#   'edges',
#   'way',
#   'edge',
#   'Note',
#   'II',
#   "'s",
#   'thing',
#   'PRECISION',
#   'someone',
#   'REALLY',
#   'moment',
#   'Note',
#   'II',
#   'it',
#   'PERFECT',
#   'thing',
#   'I',
#   'it',
#   'matte',
#   'finish',
#   'it',
#   'fingerprints',
#   'TPU',
#   'cases',
#   's-series',
#   'TPU',
#   'cases',
#   'finish',
#   'side',
#   's',
#   'shape',
#   'case',
#   "'s",
#   'back',
#   'finish',
#   'case',
#   'side',
#   's',
#   'shape',
#   'case',
#   "'s",
#   'back',
#   'back',
#   'BoxWave',
#   'Tuxedo',
#   'SuitUp',
#   'kind',
#   'matte',
#   'finish',
#   'cases',
#   'my',
#   'opinion',
#   'option',
#   'it',
#   'series',
#   'style',
#   'cases',
#   'type',
#   'side',
#   'way',
#   'glass',
#   'Note',
#   'II',
#   'protectors',
#   'style',
#   'series',
#   'cases',
#   'power',
#   'volume',
#   'rocker',
#   'buttons',
#   'them',
#   'phone',
#   'camera',
#   'flash',
#   'none',
#   'problems',
#   'BoxWave',
#   'Tuxedo',
#   'SuitUp',
#   'me',
#   'it',
#   'it',
#   'its',
#   'shiny',
#   'surface.Great',
#   'case',
#   'Best-of-breed',
#   'cases',
#   'edges',
#   'corners',
#   'protectors',
#   'type',
#   'protector',
#   'REALOOK',
#   'REALOOK',
#   "'s",
#   'screen',
#   'protector',
#   'part',
#   'Note',
#   'II',
#   "'s",
#   'screen',
#   'TPU',
#   'cases',
#   'Note',
#   'II',
#   'they',
#   'power',
#   'volume',
#   'rocker',
#   'buttons',
#   'thing',
#   'them',
#   'one',
#   'I',
#   'it',
#   'Gregg',
#   'L.',
#   'DesElmsNapa',
#   'California',
#   'USAgregg',
#   'greggdeselms',
#   'com'],
#  ['i', 'it', 'it', 'I', 'it', 'i', 'it', 'They', 'i', 'one'],
#  ['Nice',
#   'quality',
#   'price',
#   'wise',
#   'described',
#   'my',
#   'note',
#   'I',
#   'accessories',
#   'way',
#   'it',
#   'difference',
#   'what',
#   'store'],
#  ['what',
#   'it',
#   'price',
#   'Fits',
#   'damage',
#   'kickstand',
#   'touch',
#   'I',
#   'kickstand',
#   'time',
#   'ridge',
#   'front',
#   'me',
#   'phone',
#   'it',
#   'table',
#   'case',
#   'Smart',
#   'Dock',
#   'it',
#   'HDMI',
#   'it',
#   'dock',
#   'mode',
#   'HDMI'],
#  ['Bought',
#   'my',
#   'daughter',
#   'her',
#   'phone',
#   'she',
#   'it',
#   'case',
#   'soap',
#   'water'],
#  ['thick',
#   'kickstand',
#   'cases',
#   'I',
#   'thicker',
#   'corners',
#   'it',
#   'my',
#   'car',
#   'dock'],
#  ['Boxwave',
#   'case',
#   'I',
#   'my',
#   'Note',
#   'II',
#   'Bodysuit',
#   'Amazon',
#   'case',
#   'texture',
#   'I',
#   'Boxwave',
#   'case',
#   'my',
#   'Note',
#   'I',
#   'it',
#   'case',
#   'It',
#   'buttons',
#   'cutouts',
#   'buttons',
#   'it',
#   'buttons',
#   'its',
#   'case',
#   'push',
#   'phone',
#   "'s",
#   'buttons',
#   'I',
#   'buttons',
#   'work',
#   'they',
#   'time',
#   'crud/damage',
#   'Cutouts',
#   'ports/mics/camera/stylus',
#   'case',
#   'TPU',
#   'case',
#   'material',
#   'my',
#   'opinion',
#   'It',
#   'it',
#   'phone',
#   'silicone',
#   'cases',
#   'lint',
#   'stick',
#   'your',
#   'pocket',
#   'cushion',
#   'you',
#   'it'],
#  ['I',
#   'product',
#   'it',
#   'phone',
#   'it',
#   'my',
#   'signal',
#   'my',
#   'bars',
#   'none',
#   'I',
#   'calls',
#   'people',
#   'line',
#   'I',
#   'I',
#   'someone',
#   'I',
#   'cover',
#   'my',
#   'Note',
#   'my',
#   'bars',
#   'I',
#   'problems',
#   'phone',
#   'calls',
#   'I',
#   'it',
#   'it',
#   'cover',
#   'it',
#   'thing',
#   'I',
#   'my',
#   'partner',
#   'it',
#   'he',
#   'kind',
#   'phone',
#   'it',
#   'thing',
#   'his',
#   'Note',
#   'I',
#   'case',
#   'refund',
#   'It',
#   'it',
#   'case'],
#  ['Fits', 'look', 'I', 'it', 'my', 'car', 'case'],
#  ['I',
#   'way',
#   'case',
#   'feels',
#   'I',
#   'buttons',
#   'tactile',
#   'side',
#   'phone',
#   'bit',
#   'I',
#   'protection',
#   'kickstand'],
#  ['case', 'fit', 'I', 'it', 'bulky', 'protection', 'it'],
#  ['cover', 'it', 'I', 'cover', 'it'],
#  ['cover',
#   'openings',
#   'access',
#   'It',
#   'screen',
#   'surface',
#   'phone',
#   'it',
#   'what',
#   'I',
#   'it',
#   'power',
#   'volume',
#   'buttons',
#   'awkward',
#   'it',
#   'buttons',
#   'feel',
#   'I',
#   'product',
#   'anyone',
#   'protection'],
#  ['case', 'it', 'quaility', 'it', 'site'],
#  ['I',
#   'cases',
#   'my',
#   'note2',
#   'one',
#   'my',
#   'It',
#   'you',
#   'it',
#   'I',
#   'my',
#   'phone',
#   'I',
#   'it',
#   'you',
#   'it',
#   'it',
#   'back',
#   'sides',
#   'it',
#   'piece',
#   'case',
#   'I'],
#  ['I',
#   'case',
#   'piece',
#   'It',
#   'grippy',
#   'grab',
#   'you',
#   'it',
#   'Goes',
#   'my',
#   'holder',
#   'pocket',
#   'stand',
#   'stand',
#   'it',
#   'back',
#   'case',
#   'it',
#   'cases',
#   'stands',
#   'hinges',
#   'parts',
#   'blue',
#   'line',
#   'image',
#   'I',
#   'it',
#   'price'],
#  ['Flawless',
#   'fit',
#   'materials',
#   'materials',
#   'nothing',
#   'width',
#   'thickness',
#   'weight',
#   'Volume',
#   'buttons',
#   'hit',
#   'you',
#   'phone',
#   'volume',
#   'it',
#   'volume',
#   'power',
#   'buttons'],
#  ['Nice',
#   'case',
#   'value',
#   'it',
#   'hand',
#   'I',
#   'prone',
#   'it',
#   'shape/tightness',
#   'time'],
#  ['case', 'I', 'case', 'phone', 'slippery', 'I', 'it', 'one', 'job'],
#  ['I',
#   'online',
#   'case',
#   'my',
#   'Samsung',
#   'Galaxy',
#   'Note',
#   'II',
#   'product',
#   'it',
#   'design',
#   'It',
#   'protection',
#   'I',
#   'grip-ability',
#   'sides'],
#  ['I',
#   'BoxWave',
#   'cases',
#   'my',
#   'phones',
#   'they',
#   'time',
#   'I',
#   'cuts',
#   'camera',
#   'flash',
#   'S-pen',
#   'speaker',
#   'microphones',
#   'it',
#   'S-pen',
#   'corner',
#   'phone',
#   'cut',
#   'it',
#   'it',
#   'protection',
#   'corner',
#   'What',
#   'phone',
#   'corner'],
#  ['Great',
#   'design',
#   'my',
#   'phone',
#   'droppings',
#   'My',
#   'year',
#   'it',
#   'time',
#   'problem',
#   'problem',
#   'it',
#   'I',
#   'I',
#   'my',
#   'phone',
#   'my',
#   'purse',
#   'my',
#   'jeans',
#   'pockets',
#   'it',
#   'note'],
#  ...]

# %%
len(total_nouns)
# Out:
# 194439

# %%
import numpy as np

# %%
np.char.lower(total_nouns[0][0])
# Out:
# array('they',
#       dtype='<U4')

# %%
lower_total_nouns = []
for each in total_nouns:
    for one in each:
        lower_total_nouns.append(np.char.lower(one))

# %%
np.unique(lower_total_nouns)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-81-3d8d98c114a4> in <module>()
# ----> 1 np.unique(lower_total_nouns)
#
# C:\Users\maruv\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts)
#     174
#     175     """
# --> 176     ar = np.asanyarray(ar).flatten()
#     177
#     178     optional_indices = return_index or return_inverse
#
# C:\Users\maruv\Anaconda3\lib\site-packages\numpy\core\numeric.py in asanyarray(a, dtype, order)
#     531
#     532     """
# --> 533     return array(a, dtype, copy=False, order=order, subok=True)
#     534
#     535 def ascontiguousarray(a, dtype=None):
#
# MemoryError:

# %%
 np.save(data_dir + 'lowercase_nouns_total', lower_total_nouns)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-82-51c1d7a077c5> in <module>()
# ----> 1 np.save(data_dir + 'lowercase_nouns_total', lower_total_nouns)
#
# C:\Users\maruv\Anaconda3\lib\site-packages\numpy\lib\npyio.py in save(file, arr, allow_pickle, fix_imports)
#     487
#     488     try:
# --> 489         arr = np.asanyarray(arr)
#     490         format.write_array(fid, arr, allow_pickle=allow_pickle,
#     491                            pickle_kwargs=pickle_kwargs)
#
# C:\Users\maruv\Anaconda3\lib\site-packages\numpy\core\numeric.py in asanyarray(a, dtype, order)
#     531
#     532     """
# --> 533     return array(a, dtype, copy=False, order=order, subok=True)
#     534
#     535 def ascontiguousarray(a, dtype=None):
#
# MemoryError:
